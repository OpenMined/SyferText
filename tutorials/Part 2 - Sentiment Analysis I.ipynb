# %% [markdown]
# # Sentiment Analysis with SyferText

# %% [markdown]
# ## Demo Plan
#
# 1. How to use SyferText pipelines.

# %%
# Some imports
import syft as sy
from syft.generic.string import String
import torch.nn.functional as F
import torch
import syfertext
import numpy as np
import tqdm
import csv
#from sklearn.model_selection import train_test_split

hook = sy.TorchHook(torch)
# Out:
# WARNING:root:Torch was already hooked... skipping hooking process

# %%
# Preparing the work environement
me = hook.local_worker
bob = sy.VirtualWorker(hook, id = 'bob')
alice = sy.VirtualWorker(hook, id = 'alice')

crypto_provider = sy.VirtualWorker(hook, id = 'crypto_provider')

nlp = syfertext.load('en_core_web_lg', owner = me)

# %% [markdown]
# ## -3. Download the Dataset

# %% [markdown]
# ## -2. Load the Dataset

# %%
# Set the path to the dataset file
dataset_path = '../../datasets/imdb/imdb.csv'

# store the dataset as a list of dictionaries
# each dictionary has two keys, 'review' and 'label'
# the 'review' element is a PySyft String
# the 'label' element is an integer with 1 for 'positive'
# and 0 for 'negative' review
dataset_local = []

with open(dataset_path, 'r') as dataset_file:
    
    # Create a csv reader object
    reader = csv.DictReader(dataset_file)
    
    for elem in reader:
        
        # Create one entry
        example = dict(review = String(elem['review']),
                       label = 1 if elem['sentiment'] == 'positive' else 0
                      )
        
        # add to the local dataset
        dataset_local.append(example)

# %%
dataset_local[0]['review'].owner, dataset_local[0]['label']
# Out:
# (<VirtualWorker id:me #objects:0>, 1)

# %% [markdown]
# ## -1. Send the Dataset to Remote Workers

# %% [markdown]
# Let's cut the dataset into two equal parts and send each part to a different worker simulating two remote datasets:

# %%
# Create local splits
dataset_bob = dataset_local[:25000]
dataset_alice = dataset_local[25000:]

# Send the content of each split
for example in dataset_bob:
    example['review'] = example['review'].send(bob)
    
    one_hot_label = torch.zeros(2).scatter(0, torch.Tensor([example['label']]).long(), 1)
    example['label'] = one_hot_label.send(bob)
    
for example in dataset_alice:
    example['review'] = example['review'].send(alice)
    
    one_hot_label = torch.zeros(2).scatter(0, torch.Tensor([example['label']]).long(), 1)
    example['label'] = one_hot_label.send(alice)

# %%
print(type(dataset_bob[0]['review']))
print(dataset_bob[0]['review'].location)

print(type(dataset_bob[0]['label']))
print(dataset_bob[0]['label'].location)
# Out:
# <class 'syft.generic.pointers.string_pointer.StringPointer'>
# <VirtualWorker id:bob #objects:50000>
# <class 'torch.Tensor'>
# <VirtualWorker id:bob #objects:50000>

# %% [markdown]
# -----------

# %% [markdown]
# ## 0. Create a Dataset class

# %%
# This should go into the __getitem__ method of the dataloader

from torch.utils.data import Dataset

class DatasetIMDB(Dataset):
    
    def __init__(self, sets, workers, crypto_provider, nlp):
        
        self.sets = sets
        self.crypto_provider = crypto_provider
        self.workers = workers
    
        # Create a single dataset unifying all datasets
        self._create_dataset()
        
    def __getitem__(self, index):

        # get the example
        example = self.dataset[index]
        
        # Tokenize the string and get a doc pointer
        doc_ptr = nlp(example['review'])
        
        # Get the encrypted vector embedding for the document
        vector_enc = doc_ptr.get_encrypted_vector(bob, 
                                                  alice, 
                                                  crypto_provider = self.crypto_provider,
                                                  requires_grad = True
                                                 )
        
        
        # Encrypte the target label
        label_enc = example['label'].fix_precision().share(bob, 
                                                           alice, 
                                                           crypto_provider = self.crypto_provider,
                                                           requires_grad = True
                                                          ).get()
        
        return vector_enc, label_enc

    def __len__(self):
        
        # The size of the combined datasets
        return len(self.dataset)

    def _create_dataset(self):
        """Create a single dataset unifying examples from all remote datasets
        """
        # Initialize the dataset
        self.dataset = []
      
        # populate the dataset list
        for dataset in self.sets:
            for example in dataset:
                self.dataset.append(example)
                
    @staticmethod
    def collate_fn(batch):
        
        # Unzip the batch
        vectors, targets = list(zip(*batch))

        # concatenate the vectors
        vectors = torch.stack(vectors)
        
        #concatenate the labels
        targets = torch.stack(targets)
        
        return vectors, targets

# %% [markdown]
# """
# for example in dataset_local:
#
#     # Tokenize
#     doc = nlp(example['review'])
#     for token in doc:
#
#         try:
#             print(token.vector)
#
#         except KeyError: # Temporary fix while Bachir resolves the issue
#             print(np.zeros(300))
#     break
#     # Get the doc vector
#     #vector = doc.vector
# """

# %% [markdown]
# ## 1. Create a DataLoader

# %%
learning_rate = 0.001
batch_size = 32
#learning_rate = 0.01
#batch_size = 128

# %%
from torch.utils.data import DataLoader

# Instantiate a Dataset object
trainset = DatasetIMDB(sets = [dataset_bob,
                               dataset_alice],
                       workers = [bob, alice],
                       crypto_provider = crypto_provider,
                       nlp = nlp
                      )

# Instantiate the DataLoader object
trainloader = DataLoader(trainset, shuffle = True,
                         batch_size = batch_size, num_workers = 0, 
                         collate_fn = trainset.collate_fn)

# %% [markdown]
# ## 2. Create an Encrypted Classifier

# %%
class Classifier(torch.nn.Module):
    
    def __init__(self, in_features, out_features):
        super(Classifier, self).__init__()
        
        self.fc = torch.nn.Linear(in_features, out_features)
                
    def forward(self, x):
        
        logits = self.fc(x)
        
        #preds = self.sig(logits)
        probs = F.relu(logits)
        
        return probs, logits

# %% [markdown]
# Iniitialize and encrypt the classifier:

# %%
classifier = Classifier(in_features = 300, out_features = 2)

# Apply SMPC encryption
classifier = classifier.fix_precision().share(bob, alice, 
                                              crypto_provider = crypto_provider,
                                              requires_grad = True
                                              )
print(classifier)
# Out:
# Classifier(
#   (fc): Linear(in_features=300, out_features=2, bias=True)
# )

# %% [markdown]
# ## 3. Start training

# %%
# Create an optimizer
import torch.optim as optim


optim = optim.SGD(params = classifier.parameters(),
                   lr = learning_rate).fix_precision()
'''
optim = optim.Adam(params = classifier.parameters(),
                   lr = learning_rate)
'''
# Out:
# '\noptim = optim.Adam(params = classifier.parameters(),\n                   lr = learning_rate)\n'

# %%
classifier.train()

for epoch in range(10):
    
    for vectors, targets in trainloader:

        # 1). Zero out previous gradients
        optim.zero_grad()

        # 2). predict sentiments
        probs, logits = classifier(vectors)
        #print(preds.shape, logits.shape)
        # 3). Compute loss and accuracy
        #loss = torch.nn.BCEWithLogitsLoss().fix_precision()(preds, train_labels.unsqueeze(1))
        #loss = torch.nn.BCEWithLogitsLoss()(preds, targets.unsqueeze(1))
        
        #loss = targets * torch.log(preds) + (1 - targets) * torch.log((1 - preds))
        #loss = - torch.mean(loss)
        loss = ((probs -  targets)**2).sum()#.refresh()# / len(train_data)

        # Get the predicted labels
        #pred_labels = (preds > 0.5).long().squeeze(1)
        #accuracy = torch.mean((pred_labels == targets).float()) * 100
        #print(probs.get())

        preds = probs.argmax(dim=1)
        targets = targets.argmax(dim=1)
        accuracy = preds.eq(targets).sum()
        accuracy = accuracy.get().float_precision()
        accuracy = 100 * (accuracy / batch_size)
        # 4). Backpropagate the loss
        loss.backward()

        # 5). Update weights
        optim.step()
        
        # print loss
        #print(loss.get().float_precision())
        print(f"Ep {epoch} |  train loss: {loss.get().float_precision()}, train accuracy {accuracy:2} %")
        #print(f"Ep {epoch} |  train loss: {loss}, train accuracy {accuracy:2} %")
# Out:
# Ep 0 |  train loss: 32.0, train accuracy 56.25 %
# Ep 0 |  train loss: 32.0, train accuracy 56.25 %
# Ep 0 |  train loss: 31.985000610351562, train accuracy 53.125 %
# Ep 0 |  train loss: 31.929000854492188, train accuracy 50.0 %
# Ep 0 |  train loss: 31.70400047302246, train accuracy 46.875 %
# Ep 0 |  train loss: 26.20800018310547, train accuracy 56.25 %
# Ep 0 |  train loss: 17.825000762939453, train accuracy 46.875 %
# Ep 0 |  train loss: 16.364999771118164, train accuracy 46.875 %
# Ep 0 |  train loss: 15.39900016784668, train accuracy 62.5 %
# Ep 0 |  train loss: 19.198999404907227, train accuracy 34.375 %
# Ep 0 |  train loss: 15.343999862670898, train accuracy 59.375 %
# Ep 0 |  train loss: 17.95599937438965, train accuracy 37.5 %
# Ep 0 |  train loss: 16.78700065612793, train accuracy 43.75 %
# Ep 0 |  train loss: 16.79800033569336, train accuracy 31.25 %
# Ep 0 |  train loss: 16.702999114990234, train accuracy 53.125 %
# Ep 0 |  train loss: 15.774999618530273, train accuracy 56.25 %
# Ep 0 |  train loss: 18.145000457763672, train accuracy 25.0 %
# Ep 0 |  train loss: 12.605999946594238, train accuracy 75.0 %
# Ep 0 |  train loss: 19.26099967956543, train accuracy 50.0 %
# Ep 0 |  train loss: 16.36199951171875, train accuracy 50.0 %
# Ep 0 |  train loss: 16.02899932861328, train accuracy 56.25 %
# Ep 0 |  train loss: 15.947999954223633, train accuracy 50.0 %
# Ep 0 |  train loss: 15.918999671936035, train accuracy 53.125 %
# Ep 0 |  train loss: 16.398000717163086, train accuracy 40.625 %
# Ep 0 |  train loss: 16.149999618530273, train accuracy 46.875 %
# Ep 0 |  train loss: 15.946999549865723, train accuracy 56.25 %
# Ep 0 |  train loss: 15.984000205993652, train accuracy 40.625 %
# Ep 0 |  train loss: 15.562000274658203, train accuracy 59.375 %
# Ep 0 |  train loss: 17.423999786376953, train accuracy 34.375 %
# Ep 0 |  train loss: 15.11400032043457, train accuracy 62.5 %
# Ep 0 |  train loss: 19.104000091552734, train accuracy 34.375 %
# Ep 0 |  train loss: 16.375, train accuracy 46.875 %
# Ep 0 |  train loss: 15.652000427246094, train accuracy 71.875 %
# Ep 0 |  train loss: 15.855999946594238, train accuracy 59.375 %
# Ep 0 |  train loss: 15.701000213623047, train accuracy 62.5 %
# Ep 0 |  train loss: 16.172000885009766, train accuracy 53.125 %
# Ep 0 |  train loss: 16.89900016784668, train accuracy 37.5 %
# Ep 0 |  train loss: 14.887999534606934, train accuracy 62.5 %
# Ep 0 |  train loss: 17.26099967956543, train accuracy 40.625 %
# Ep 0 |  train loss: 15.958999633789062, train accuracy 53.125 %
# Ep 0 |  train loss: 15.638999938964844, train accuracy 71.875 %
# Ep 0 |  train loss: 15.819000244140625, train accuracy 59.375 %
# Ep 0 |  train loss: 15.54800033569336, train accuracy 53.125 %
# Ep 0 |  train loss: 15.508999824523926, train accuracy 59.375 %
# Ep 0 |  train loss: 16.32200050354004, train accuracy 46.875 %
# Ep 0 |  train loss: 15.75, train accuracy 65.625 %
# Ep 0 |  train loss: 15.682999610900879, train accuracy 50.0 %
# Ep 0 |  train loss: 15.710000038146973, train accuracy 56.25 %
# Ep 0 |  train loss: 16.06999969482422, train accuracy 53.125 %
# Ep 0 |  train loss: 15.800999641418457, train accuracy 53.125 %
# Ep 0 |  train loss: 15.925999641418457, train accuracy 53.125 %
# Ep 0 |  train loss: 14.727999687194824, train accuracy 62.5 %
# Ep 0 |  train loss: 15.829000473022461, train accuracy 56.25 %
# Ep 0 |  train loss: 17.4950008392334, train accuracy 34.375 %
# Ep 0 |  train loss: 16.329999923706055, train accuracy 50.0 %
# Ep 0 |  train loss: 15.383999824523926, train accuracy 65.625 %
# Ep 0 |  train loss: 15.467000007629395, train accuracy 62.5 %
# Ep 0 |  train loss: 15.324999809265137, train accuracy 68.75 %
# Ep 0 |  train loss: 15.461000442504883, train accuracy 65.625 %
# Ep 0 |  train loss: 16.35099983215332, train accuracy 46.875 %
# Ep 0 |  train loss: 15.369999885559082, train accuracy 65.625 %
# Ep 0 |  train loss: 15.581999778747559, train accuracy 62.5 %
# Ep 0 |  train loss: 15.522000312805176, train accuracy 71.875 %
# Ep 0 |  train loss: 15.192999839782715, train accuracy 62.5 %
# Ep 0 |  train loss: 14.428999900817871, train accuracy 65.625 %
# Ep 0 |  train loss: 14.720000267028809, train accuracy 59.375 %
# Ep 0 |  train loss: 15.041000366210938, train accuracy 59.375 %
# Ep 0 |  train loss: 17.773000717163086, train accuracy 31.25 %
# Ep 0 |  train loss: 14.718000411987305, train accuracy 56.25 %
# Ep 0 |  train loss: 14.345999717712402, train accuracy 62.5 %
# Ep 0 |  train loss: 16.34000015258789, train accuracy 50.0 %
# Ep 0 |  train loss: 15.654999732971191, train accuracy 56.25 %
# Ep 0 |  train loss: 15.520000457763672, train accuracy 53.125 %
# Ep 0 |  train loss: 15.118000030517578, train accuracy 78.125 %
# Ep 0 |  train loss: 15.326000213623047, train accuracy 78.125 %
# Ep 0 |  train loss: 15.034000396728516, train accuracy 71.875 %
# Ep 0 |  train loss: 15.654999732971191, train accuracy 53.125 %
# Ep 0 |  train loss: 14.968999862670898, train accuracy 65.625 %
# Ep 0 |  train loss: 15.741999626159668, train accuracy 50.0 %
# Ep 0 |  train loss: 15.61400032043457, train accuracy 56.25 %
# Ep 0 |  train loss: 16.80900001525879, train accuracy 40.625 %
# Ep 0 |  train loss: 14.928000450134277, train accuracy 68.75 %
# Ep 0 |  train loss: 14.163999557495117, train accuracy 62.5 %
# Ep 0 |  train loss: 15.467000007629395, train accuracy 53.125 %
# Ep 0 |  train loss: 16.285999298095703, train accuracy 37.5 %
# Ep 0 |  train loss: 14.138999938964844, train accuracy 78.125 %
# Ep 0 |  train loss: 16.92099952697754, train accuracy 50.0 %
# Ep 0 |  train loss: 15.539999961853027, train accuracy 50.0 %
# Ep 0 |  train loss: 15.206000328063965, train accuracy 62.5 %
# Ep 0 |  train loss: 15.199000358581543, train accuracy 62.5 %
# Ep 0 |  train loss: 16.034000396728516, train accuracy 50.0 %
# Ep 0 |  train loss: 16.084999084472656, train accuracy 46.875 %
# Ep 0 |  train loss: 14.399999618530273, train accuracy 68.75 %
# Ep 0 |  train loss: 15.5649995803833, train accuracy 46.875 %
# Ep 0 |  train loss: 15.116999626159668, train accuracy 62.5 %
# Ep 0 |  train loss: 15.354999542236328, train accuracy 59.375 %
# Ep 0 |  train loss: 15.244000434875488, train accuracy 68.75 %
# Ep 0 |  train loss: 15.414999961853027, train accuracy 59.375 %
# Ep 0 |  train loss: 16.43199920654297, train accuracy 40.625 %
# Ep 0 |  train loss: 14.819999694824219, train accuracy 62.5 %
# Ep 0 |  train loss: 15.25, train accuracy 68.75 %
# Ep 0 |  train loss: 15.517999649047852, train accuracy 62.5 %
# Ep 0 |  train loss: 15.14799976348877, train accuracy 56.25 %
# Ep 0 |  train loss: 14.668999671936035, train accuracy 68.75 %
# Ep 0 |  train loss: 14.699000358581543, train accuracy 68.75 %
# Ep 0 |  train loss: 13.996999740600586, train accuracy 65.625 %
# Ep 0 |  train loss: 14.00100040435791, train accuracy 62.5 %
# Ep 0 |  train loss: 16.71299934387207, train accuracy 46.875 %
# Ep 0 |  train loss: 15.331000328063965, train accuracy 65.625 %
# Ep 0 |  train loss: 15.70199966430664, train accuracy 56.25 %
# Ep 0 |  train loss: 15.446000099182129, train accuracy 50.0 %
# Ep 0 |  train loss: 15.04800033569336, train accuracy 65.625 %
# Ep 0 |  train loss: 13.788999557495117, train accuracy 78.125 %
# Ep 0 |  train loss: 15.157999992370605, train accuracy 65.625 %
# Ep 0 |  train loss: 16.582000732421875, train accuracy 40.625 %
# Ep 0 |  train loss: 15.567000389099121, train accuracy 56.25 %
# Ep 0 |  train loss: 16.839000701904297, train accuracy 46.875 %
# Ep 0 |  train loss: 15.04800033569336, train accuracy 59.375 %
# Ep 0 |  train loss: 15.4399995803833, train accuracy 53.125 %
# Ep 0 |  train loss: 15.876999855041504, train accuracy 46.875 %
# Ep 0 |  train loss: 14.96399974822998, train accuracy 56.25 %
# Ep 0 |  train loss: 14.543999671936035, train accuracy 68.75 %
# Ep 0 |  train loss: 14.217000007629395, train accuracy 59.375 %
# Ep 0 |  train loss: 15.385000228881836, train accuracy 50.0 %
# Ep 0 |  train loss: 15.116000175476074, train accuracy 59.375 %
# Ep 0 |  train loss: 13.927000045776367, train accuracy 62.5 %
# Ep 0 |  train loss: 15.050000190734863, train accuracy 59.375 %
# Ep 0 |  train loss: 14.694999694824219, train accuracy 71.875 %
# Ep 0 |  train loss: 14.807000160217285, train accuracy 65.625 %
# Ep 0 |  train loss: 14.970000267028809, train accuracy 53.125 %
# Ep 0 |  train loss: 14.906000137329102, train accuracy 62.5 %
# Ep 0 |  train loss: 14.934000015258789, train accuracy 71.875 %
# Ep 0 |  train loss: 15.786999702453613, train accuracy 46.875 %
# Ep 0 |  train loss: 15.11400032043457, train accuracy 65.625 %
# Ep 0 |  train loss: 16.399999618530273, train accuracy 43.75 %
# Ep 0 |  train loss: 14.520999908447266, train accuracy 65.625 %
# Ep 0 |  train loss: 13.99899959564209, train accuracy 56.25 %
# Ep 0 |  train loss: 15.800999641418457, train accuracy 56.25 %
# Ep 0 |  train loss: 15.642000198364258, train accuracy 50.0 %
# Ep 0 |  train loss: 14.565999984741211, train accuracy 68.75 %
# Ep 0 |  train loss: 14.86299991607666, train accuracy 62.5 %
# Ep 0 |  train loss: 14.081999778747559, train accuracy 75.0 %
# Ep 0 |  train loss: 15.527999877929688, train accuracy 53.125 %
# Ep 0 |  train loss: 15.032999992370605, train accuracy 50.0 %
# Ep 0 |  train loss: 15.034000396728516, train accuracy 65.625 %
# Ep 0 |  train loss: 15.246000289916992, train accuracy 53.125 %
# Ep 0 |  train loss: 15.079999923706055, train accuracy 68.75 %
# Ep 0 |  train loss: 14.357000350952148, train accuracy 65.625 %
# Ep 0 |  train loss: 14.24899959564209, train accuracy 65.625 %
# Ep 0 |  train loss: 15.522000312805176, train accuracy 46.875 %
# Ep 0 |  train loss: 14.873000144958496, train accuracy 68.75 %
# Ep 0 |  train loss: 15.414999961853027, train accuracy 59.375 %
# Ep 0 |  train loss: 15.215999603271484, train accuracy 65.625 %
# Ep 0 |  train loss: 16.090999603271484, train accuracy 50.0 %
# Ep 0 |  train loss: 14.710000038146973, train accuracy 65.625 %
# Ep 0 |  train loss: 14.409000396728516, train accuracy 62.5 %
# Ep 0 |  train loss: 14.340999603271484, train accuracy 75.0 %
# Ep 0 |  train loss: 15.552000045776367, train accuracy 56.25 %
# Ep 0 |  train loss: 14.095000267028809, train accuracy 75.0 %
# Ep 0 |  train loss: 13.024999618530273, train accuracy 65.625 %
# Ep 0 |  train loss: 16.79800033569336, train accuracy 40.625 %
# Ep 0 |  train loss: 14.845000267028809, train accuracy 59.375 %
# Ep 0 |  train loss: 14.932000160217285, train accuracy 68.75 %
# Ep 0 |  train loss: 14.711000442504883, train accuracy 62.5 %
# Ep 0 |  train loss: 14.706000328063965, train accuracy 59.375 %
# Ep 0 |  train loss: 14.493000030517578, train accuracy 59.375 %
# Ep 0 |  train loss: 13.411999702453613, train accuracy 78.125 %
# Ep 0 |  train loss: 16.1560001373291, train accuracy 53.125 %
# Ep 0 |  train loss: 15.42199993133545, train accuracy 65.625 %
# Ep 0 |  train loss: 13.29699993133545, train accuracy 81.25 %
# Ep 0 |  train loss: 16.19499969482422, train accuracy 43.75 %
# Ep 0 |  train loss: 12.949000358581543, train accuracy 84.375 %
# Ep 0 |  train loss: 14.413999557495117, train accuracy 75.0 %
# Ep 0 |  train loss: 15.157999992370605, train accuracy 56.25 %
# Ep 0 |  train loss: 15.406999588012695, train accuracy 37.5 %
# Ep 0 |  train loss: 14.147000312805176, train accuracy 68.75 %
# Ep 0 |  train loss: 14.236000061035156, train accuracy 65.625 %
# Ep 0 |  train loss: 13.97599983215332, train accuracy 65.625 %
# Ep 0 |  train loss: 14.779000282287598, train accuracy 53.125 %
# Ep 0 |  train loss: 14.810999870300293, train accuracy 59.375 %
# Ep 0 |  train loss: 15.305999755859375, train accuracy 56.25 %
# Ep 0 |  train loss: 15.104000091552734, train accuracy 50.0 %
# Ep 0 |  train loss: 14.163000106811523, train accuracy 75.0 %
# Ep 0 |  train loss: 14.907999992370605, train accuracy 53.125 %
# Ep 0 |  train loss: 14.991999626159668, train accuracy 65.625 %
# Ep 0 |  train loss: 14.022000312805176, train accuracy 75.0 %
# Ep 0 |  train loss: 14.555999755859375, train accuracy 65.625 %
# Ep 0 |  train loss: 14.008000373840332, train accuracy 56.25 %
# Ep 0 |  train loss: 14.300999641418457, train accuracy 71.875 %
# Ep 0 |  train loss: 14.395000457763672, train accuracy 71.875 %
# Ep 0 |  train loss: 14.543999671936035, train accuracy 59.375 %
# Ep 0 |  train loss: 13.991000175476074, train accuracy 62.5 %
# Ep 0 |  train loss: 15.281000137329102, train accuracy 62.5 %
# Ep 0 |  train loss: 14.66100025177002, train accuracy 68.75 %
# Ep 0 |  train loss: 12.437000274658203, train accuracy 84.375 %
# Ep 0 |  train loss: 14.993000030517578, train accuracy 62.5 %
# Ep 0 |  train loss: 15.060999870300293, train accuracy 50.0 %
# Ep 0 |  train loss: 14.687999725341797, train accuracy 68.75 %
# Ep 0 |  train loss: 13.85099983215332, train accuracy 78.125 %
# Ep 0 |  train loss: 15.008999824523926, train accuracy 62.5 %
# Ep 0 |  train loss: 14.14799976348877, train accuracy 75.0 %
# Ep 0 |  train loss: 13.404999732971191, train accuracy 53.125 %
# Ep 0 |  train loss: 14.802000045776367, train accuracy 59.375 %
# Ep 0 |  train loss: 14.32699966430664, train accuracy 62.5 %
# Ep 0 |  train loss: 14.756999969482422, train accuracy 62.5 %
# Ep 0 |  train loss: 14.470999717712402, train accuracy 71.875 %
# Ep 0 |  train loss: 13.657999992370605, train accuracy 84.375 %
# Ep 0 |  train loss: 14.920000076293945, train accuracy 75.0 %
# Ep 0 |  train loss: 14.1850004196167, train accuracy 65.625 %
# Ep 0 |  train loss: 14.71399974822998, train accuracy 71.875 %
# Ep 0 |  train loss: 12.777000427246094, train accuracy 68.75 %
# Ep 0 |  train loss: 15.430999755859375, train accuracy 53.125 %
# Ep 0 |  train loss: 13.501999855041504, train accuracy 78.125 %
# Ep 0 |  train loss: 14.855999946594238, train accuracy 68.75 %
# Ep 0 |  train loss: 15.776000022888184, train accuracy 56.25 %
# Ep 0 |  train loss: 13.597999572753906, train accuracy 65.625 %
# Ep 0 |  train loss: 15.119999885559082, train accuracy 46.875 %
# Ep 0 |  train loss: 15.406999588012695, train accuracy 62.5 %
# Ep 0 |  train loss: 14.23799991607666, train accuracy 68.75 %
# Ep 0 |  train loss: 14.22599983215332, train accuracy 59.375 %
# Ep 0 |  train loss: 14.480999946594238, train accuracy 65.625 %
# Ep 0 |  train loss: 13.984000205993652, train accuracy 62.5 %
# Ep 0 |  train loss: 15.017000198364258, train accuracy 56.25 %
# Ep 0 |  train loss: 13.657999992370605, train accuracy 71.875 %
# Ep 0 |  train loss: 14.734999656677246, train accuracy 50.0 %
# Ep 0 |  train loss: 13.840999603271484, train accuracy 68.75 %
# Ep 0 |  train loss: 14.354999542236328, train accuracy 78.125 %
# Ep 0 |  train loss: 13.359999656677246, train accuracy 68.75 %
# Ep 0 |  train loss: 13.197999954223633, train accuracy 81.25 %
# Ep 0 |  train loss: 13.722000122070312, train accuracy 81.25 %
# Ep 0 |  train loss: 14.47599983215332, train accuracy 71.875 %
# Ep 0 |  train loss: 15.145999908447266, train accuracy 65.625 %
# Ep 0 |  train loss: 15.722999572753906, train accuracy 43.75 %
# Ep 0 |  train loss: 13.23900032043457, train accuracy 84.375 %
# Ep 0 |  train loss: 13.371999740600586, train accuracy 81.25 %
# Ep 0 |  train loss: 12.395999908447266, train accuracy 81.25 %
# Ep 0 |  train loss: 17.058000564575195, train accuracy 50.0 %
# Ep 0 |  train loss: 13.998000144958496, train accuracy 87.5 %
# Ep 0 |  train loss: 14.079000473022461, train accuracy 78.125 %
# Ep 0 |  train loss: 13.694999694824219, train accuracy 81.25 %
# Ep 0 |  train loss: 13.600000381469727, train accuracy 71.875 %
# Ep 0 |  train loss: 13.616999626159668, train accuracy 75.0 %
# Ep 0 |  train loss: 14.034000396728516, train accuracy 56.25 %
# Ep 0 |  train loss: 14.369999885559082, train accuracy 71.875 %
# Ep 0 |  train loss: 15.10099983215332, train accuracy 46.875 %
# Ep 0 |  train loss: 12.805000305175781, train accuracy 84.375 %
# Ep 0 |  train loss: 14.222999572753906, train accuracy 59.375 %
# Ep 0 |  train loss: 13.354000091552734, train accuracy 75.0 %
# Ep 0 |  train loss: 15.04800033569336, train accuracy 59.375 %
# Ep 0 |  train loss: 14.819000244140625, train accuracy 65.625 %
# Ep 0 |  train loss: 16.617000579833984, train accuracy 40.625 %
# Ep 0 |  train loss: 14.39799976348877, train accuracy 71.875 %
# Ep 0 |  train loss: 14.300999641418457, train accuracy 68.75 %
# Ep 0 |  train loss: 13.508000373840332, train accuracy 68.75 %
# Ep 0 |  train loss: 13.876999855041504, train accuracy 78.125 %
# Ep 0 |  train loss: 14.279999732971191, train accuracy 68.75 %
# Ep 0 |  train loss: 12.833999633789062, train accuracy 75.0 %
# Ep 0 |  train loss: 15.267999649047852, train accuracy 59.375 %
# Ep 0 |  train loss: 13.788000106811523, train accuracy 75.0 %
# Ep 0 |  train loss: 13.652000427246094, train accuracy 68.75 %
# Ep 0 |  train loss: 14.54800033569336, train accuracy 65.625 %
# Ep 0 |  train loss: 13.678000450134277, train accuracy 75.0 %
# Ep 0 |  train loss: 15.199000358581543, train accuracy 59.375 %
# Ep 0 |  train loss: 13.75, train accuracy 68.75 %
# Ep 0 |  train loss: 13.545999526977539, train accuracy 68.75 %
# Ep 0 |  train loss: 15.92300033569336, train accuracy 53.125 %
# Ep 0 |  train loss: 14.069999694824219, train accuracy 81.25 %
# Ep 0 |  train loss: 14.131999969482422, train accuracy 68.75 %
# Ep 0 |  train loss: 14.409000396728516, train accuracy 62.5 %
# Ep 0 |  train loss: 12.87399959564209, train accuracy 75.0 %
# Ep 0 |  train loss: 12.156000137329102, train accuracy 71.875 %
# Ep 0 |  train loss: 14.11299991607666, train accuracy 71.875 %
# Ep 0 |  train loss: 13.996999740600586, train accuracy 71.875 %
# Ep 0 |  train loss: 13.387999534606934, train accuracy 71.875 %
# Ep 0 |  train loss: 13.111000061035156, train accuracy 81.25 %
# Ep 0 |  train loss: 16.534000396728516, train accuracy 40.625 %
# Ep 0 |  train loss: 14.60099983215332, train accuracy 65.625 %
# Ep 0 |  train loss: 13.428999900817871, train accuracy 71.875 %
# Ep 0 |  train loss: 14.414999961853027, train accuracy 75.0 %
# Ep 0 |  train loss: 12.814000129699707, train accuracy 78.125 %
# Ep 0 |  train loss: 13.654999732971191, train accuracy 65.625 %
# Ep 0 |  train loss: 14.288000106811523, train accuracy 62.5 %
# Ep 0 |  train loss: 17.649999618530273, train accuracy 43.75 %
# Ep 0 |  train loss: 12.935999870300293, train accuracy 81.25 %
# Ep 0 |  train loss: 13.21399974822998, train accuracy 75.0 %
# Ep 0 |  train loss: 15.27400016784668, train accuracy 59.375 %
# Ep 0 |  train loss: 13.829999923706055, train accuracy 78.125 %
# Ep 0 |  train loss: 14.109000205993652, train accuracy 62.5 %
# Ep 0 |  train loss: 13.517999649047852, train accuracy 68.75 %
# Ep 0 |  train loss: 13.368000030517578, train accuracy 75.0 %
# Ep 0 |  train loss: 13.319000244140625, train accuracy 75.0 %
# Ep 0 |  train loss: 13.590999603271484, train accuracy 75.0 %
# Ep 0 |  train loss: 14.77400016784668, train accuracy 65.625 %
# Ep 0 |  train loss: 13.70199966430664, train accuracy 68.75 %
# Ep 0 |  train loss: 13.595999717712402, train accuracy 71.875 %
# Ep 0 |  train loss: 15.262999534606934, train accuracy 62.5 %
# Ep 0 |  train loss: 13.038000106811523, train accuracy 68.75 %
# Ep 0 |  train loss: 13.604000091552734, train accuracy 71.875 %
# Ep 0 |  train loss: 14.135000228881836, train accuracy 62.5 %
# Ep 0 |  train loss: 13.942000389099121, train accuracy 71.875 %
# Ep 0 |  train loss: 13.279999732971191, train accuracy 78.125 %
# Ep 0 |  train loss: 12.395999908447266, train accuracy 81.25 %
# Ep 0 |  train loss: 14.222999572753906, train accuracy 62.5 %
# Ep 0 |  train loss: 14.64900016784668, train accuracy 62.5 %
# Ep 0 |  train loss: 13.843999862670898, train accuracy 71.875 %
# Ep 0 |  train loss: 13.892999649047852, train accuracy 78.125 %
# Ep 0 |  train loss: 14.562000274658203, train accuracy 65.625 %
# Ep 0 |  train loss: 13.02299976348877, train accuracy 78.125 %
# Ep 0 |  train loss: 13.670000076293945, train accuracy 65.625 %
# Ep 0 |  train loss: 12.07699966430664, train accuracy 81.25 %
# Ep 0 |  train loss: 14.383000373840332, train accuracy 59.375 %
# Ep 0 |  train loss: 14.279000282287598, train accuracy 68.75 %
# Ep 0 |  train loss: 12.142000198364258, train accuracy 75.0 %
# Ep 0 |  train loss: 11.555000305175781, train accuracy 68.75 %
# Ep 0 |  train loss: 13.532999992370605, train accuracy 65.625 %
# Ep 0 |  train loss: 14.598999977111816, train accuracy 56.25 %
# Ep 0 |  train loss: 12.805000305175781, train accuracy 71.875 %
# Ep 0 |  train loss: 13.579000473022461, train accuracy 62.5 %
# Ep 0 |  train loss: 13.21500015258789, train accuracy 75.0 %
# Ep 0 |  train loss: 13.883000373840332, train accuracy 81.25 %
# Ep 0 |  train loss: 14.034000396728516, train accuracy 68.75 %
# Ep 0 |  train loss: 14.513999938964844, train accuracy 65.625 %
# Ep 0 |  train loss: 14.232000350952148, train accuracy 65.625 %
# Ep 0 |  train loss: 13.137999534606934, train accuracy 75.0 %
# Ep 0 |  train loss: 13.984000205993652, train accuracy 71.875 %
# Ep 0 |  train loss: 12.081999778747559, train accuracy 84.375 %
# Ep 0 |  train loss: 14.244000434875488, train accuracy 68.75 %
# Ep 0 |  train loss: 12.333999633789062, train accuracy 71.875 %
# Ep 0 |  train loss: 12.85200023651123, train accuracy 75.0 %
# Ep 0 |  train loss: 12.29699993133545, train accuracy 81.25 %
# Ep 0 |  train loss: 14.956999778747559, train accuracy 50.0 %
# Ep 0 |  train loss: 13.857999801635742, train accuracy 75.0 %
# Ep 0 |  train loss: 14.86400032043457, train accuracy 62.5 %
# Ep 0 |  train loss: 13.8149995803833, train accuracy 78.125 %
# Ep 0 |  train loss: 14.352999687194824, train accuracy 62.5 %
# Ep 0 |  train loss: 14.654000282287598, train accuracy 75.0 %
# Ep 0 |  train loss: 12.848999977111816, train accuracy 71.875 %
# Ep 0 |  train loss: 11.883999824523926, train accuracy 87.5 %
# Ep 0 |  train loss: 13.680999755859375, train accuracy 65.625 %
# Ep 0 |  train loss: 14.166000366210938, train accuracy 65.625 %
# Ep 0 |  train loss: 12.104000091552734, train accuracy 78.125 %
# Ep 0 |  train loss: 14.178000450134277, train accuracy 75.0 %
# Ep 0 |  train loss: 14.505000114440918, train accuracy 68.75 %
# Ep 0 |  train loss: 11.907999992370605, train accuracy 87.5 %
# Ep 0 |  train loss: 14.342000007629395, train accuracy 71.875 %
# Ep 0 |  train loss: 13.281999588012695, train accuracy 84.375 %
# Ep 0 |  train loss: 12.756999969482422, train accuracy 75.0 %
# Ep 0 |  train loss: 13.574000358581543, train accuracy 65.625 %
# Ep 0 |  train loss: 14.253999710083008, train accuracy 65.625 %
# Ep 0 |  train loss: 14.524999618530273, train accuracy 59.375 %
# Ep 0 |  train loss: 13.940999984741211, train accuracy 75.0 %
# Ep 0 |  train loss: 13.791000366210938, train accuracy 65.625 %
# Ep 0 |  train loss: 13.052000045776367, train accuracy 78.125 %
# Ep 0 |  train loss: 12.956999778747559, train accuracy 71.875 %
# Ep 0 |  train loss: 13.10099983215332, train accuracy 68.75 %
# Ep 0 |  train loss: 15.57800006866455, train accuracy 53.125 %
# Ep 0 |  train loss: 14.130000114440918, train accuracy 56.25 %
# Ep 0 |  train loss: 13.670999526977539, train accuracy 65.625 %
# Ep 0 |  train loss: 14.406999588012695, train accuracy 59.375 %
# Ep 0 |  train loss: 12.954000473022461, train accuracy 78.125 %
# Ep 0 |  train loss: 12.368000030517578, train accuracy 81.25 %
# Ep 0 |  train loss: 12.230999946594238, train accuracy 84.375 %
# Ep 0 |  train loss: 13.902999877929688, train accuracy 62.5 %
# Ep 0 |  train loss: 15.505000114440918, train accuracy 56.25 %
# Ep 0 |  train loss: 14.57800006866455, train accuracy 56.25 %
# Ep 0 |  train loss: 14.434000015258789, train accuracy 62.5 %
# Ep 0 |  train loss: 12.319999694824219, train accuracy 78.125 %
# Ep 0 |  train loss: 13.059000015258789, train accuracy 71.875 %
# Ep 0 |  train loss: 14.692999839782715, train accuracy 56.25 %
# Ep 0 |  train loss: 13.572999954223633, train accuracy 75.0 %
# Ep 0 |  train loss: 13.920999526977539, train accuracy 71.875 %
# Ep 0 |  train loss: 13.3149995803833, train accuracy 71.875 %
# Ep 0 |  train loss: 12.994000434875488, train accuracy 78.125 %
# Ep 0 |  train loss: 14.359000205993652, train accuracy 59.375 %
# Ep 0 |  train loss: 14.329000473022461, train accuracy 71.875 %
# Ep 0 |  train loss: 11.979000091552734, train accuracy 81.25 %
# Ep 0 |  train loss: 13.581999778747559, train accuracy 71.875 %
# Ep 0 |  train loss: 14.045000076293945, train accuracy 65.625 %
# Ep 0 |  train loss: 13.293999671936035, train accuracy 71.875 %
# Ep 0 |  train loss: 13.937000274658203, train accuracy 78.125 %
# Ep 0 |  train loss: 14.539999961853027, train accuracy 71.875 %
# Ep 0 |  train loss: 12.930999755859375, train accuracy 65.625 %
# Ep 0 |  train loss: 13.314000129699707, train accuracy 75.0 %
# Ep 0 |  train loss: 12.64900016784668, train accuracy 81.25 %
# Ep 0 |  train loss: 13.581999778747559, train accuracy 68.75 %
# Ep 0 |  train loss: 13.734999656677246, train accuracy 65.625 %
# Ep 0 |  train loss: 12.414999961853027, train accuracy 84.375 %
# Ep 0 |  train loss: 14.277999877929688, train accuracy 65.625 %
# Ep 0 |  train loss: 13.633000373840332, train accuracy 78.125 %
# Ep 0 |  train loss: 14.102999687194824, train accuracy 78.125 %
# Ep 0 |  train loss: 14.196999549865723, train accuracy 65.625 %
# Ep 0 |  train loss: 14.067999839782715, train accuracy 65.625 %
# Ep 0 |  train loss: 14.097000122070312, train accuracy 62.5 %
# Ep 0 |  train loss: 11.909000396728516, train accuracy 71.875 %
# Ep 0 |  train loss: 12.638999938964844, train accuracy 75.0 %
# Ep 0 |  train loss: 12.704000473022461, train accuracy 81.25 %
# Ep 0 |  train loss: 12.927000045776367, train accuracy 71.875 %
# Ep 0 |  train loss: 15.626999855041504, train accuracy 56.25 %
# Ep 0 |  train loss: 11.789999961853027, train accuracy 84.375 %
# Ep 0 |  train loss: 12.192000389099121, train accuracy 71.875 %
# Ep 0 |  train loss: 13.88700008392334, train accuracy 62.5 %
# Ep 0 |  train loss: 14.95300006866455, train accuracy 62.5 %
# Ep 0 |  train loss: 12.711999893188477, train accuracy 75.0 %
# Ep 0 |  train loss: 13.555000305175781, train accuracy 71.875 %
# Ep 0 |  train loss: 14.494999885559082, train accuracy 65.625 %
# Ep 0 |  train loss: 13.357000350952148, train accuracy 62.5 %
# Ep 0 |  train loss: 11.83899974822998, train accuracy 87.5 %
# Ep 0 |  train loss: 14.937999725341797, train accuracy 62.5 %
# Ep 0 |  train loss: 13.199000358581543, train accuracy 65.625 %
# Ep 0 |  train loss: 13.239999771118164, train accuracy 65.625 %
# Ep 0 |  train loss: 14.079000473022461, train accuracy 56.25 %
# Ep 0 |  train loss: 12.85200023651123, train accuracy 65.625 %
# Ep 0 |  train loss: 13.967000007629395, train accuracy 68.75 %
# Ep 0 |  train loss: 12.190999984741211, train accuracy 78.125 %
# Ep 0 |  train loss: 13.413999557495117, train accuracy 75.0 %
# Ep 0 |  train loss: 16.0049991607666, train accuracy 46.875 %
# Ep 0 |  train loss: 14.060999870300293, train accuracy 71.875 %
# Ep 0 |  train loss: 12.267000198364258, train accuracy 81.25 %
# Ep 0 |  train loss: 12.605999946594238, train accuracy 71.875 %
# Ep 0 |  train loss: 13.46399974822998, train accuracy 62.5 %
# Ep 0 |  train loss: 12.392000198364258, train accuracy 78.125 %
# Ep 0 |  train loss: 12.15999984741211, train accuracy 75.0 %
# Ep 0 |  train loss: 13.612000465393066, train accuracy 65.625 %
# Ep 0 |  train loss: 13.277000427246094, train accuracy 71.875 %
# Ep 0 |  train loss: 11.6850004196167, train accuracy 78.125 %
# Ep 0 |  train loss: 12.84000015258789, train accuracy 75.0 %
# Ep 0 |  train loss: 12.187000274658203, train accuracy 84.375 %
# Ep 0 |  train loss: 13.489999771118164, train accuracy 71.875 %
# Ep 0 |  train loss: 12.814000129699707, train accuracy 81.25 %
# Ep 0 |  train loss: 13.487000465393066, train accuracy 71.875 %
# Ep 0 |  train loss: 13.119000434875488, train accuracy 75.0 %
# Ep 0 |  train loss: 12.949000358581543, train accuracy 65.625 %
# Ep 0 |  train loss: 12.001999855041504, train accuracy 81.25 %
# Ep 0 |  train loss: 10.748000144958496, train accuracy 87.5 %
# Ep 0 |  train loss: 12.809000015258789, train accuracy 71.875 %
# Ep 0 |  train loss: 12.991000175476074, train accuracy 78.125 %
# Ep 0 |  train loss: 10.930999755859375, train accuracy 78.125 %
# Ep 0 |  train loss: 12.930000305175781, train accuracy 81.25 %
# Ep 0 |  train loss: 13.343000411987305, train accuracy 75.0 %
# Ep 0 |  train loss: 13.364999771118164, train accuracy 71.875 %
# Ep 0 |  train loss: 16.621000289916992, train accuracy 53.125 %
# Ep 0 |  train loss: 13.79800033569336, train accuracy 68.75 %
# Ep 0 |  train loss: 12.281999588012695, train accuracy 84.375 %
# Ep 0 |  train loss: 12.298999786376953, train accuracy 71.875 %
# Ep 0 |  train loss: 12.791000366210938, train accuracy 78.125 %
# Ep 0 |  train loss: 13.329999923706055, train accuracy 71.875 %
# Ep 0 |  train loss: 12.142000198364258, train accuracy 71.875 %
# Ep 0 |  train loss: 13.008000373840332, train accuracy 71.875 %
# Ep 0 |  train loss: 11.47700023651123, train accuracy 81.25 %
# Ep 0 |  train loss: 14.345999717712402, train accuracy 65.625 %
# Ep 0 |  train loss: 12.437999725341797, train accuracy 78.125 %
# Ep 0 |  train loss: 11.248000144958496, train accuracy 75.0 %
# Ep 0 |  train loss: 11.5649995803833, train accuracy 75.0 %
# Ep 0 |  train loss: 14.774999618530273, train accuracy 56.25 %
# Ep 0 |  train loss: 13.081999778747559, train accuracy 75.0 %
# Ep 0 |  train loss: 13.317000389099121, train accuracy 65.625 %
# Ep 0 |  train loss: 13.437000274658203, train accuracy 68.75 %
# Ep 0 |  train loss: 12.99899959564209, train accuracy 62.5 %
# Ep 0 |  train loss: 12.890000343322754, train accuracy 78.125 %
# Ep 0 |  train loss: 12.147000312805176, train accuracy 75.0 %
# Ep 0 |  train loss: 11.824999809265137, train accuracy 84.375 %
# Ep 0 |  train loss: 13.769000053405762, train accuracy 68.75 %
# Ep 0 |  train loss: 11.880000114440918, train accuracy 81.25 %
# Ep 0 |  train loss: 11.704999923706055, train accuracy 87.5 %
# Ep 0 |  train loss: 13.236000061035156, train accuracy 62.5 %
# Ep 0 |  train loss: 12.795000076293945, train accuracy 75.0 %
# Ep 0 |  train loss: 12.647000312805176, train accuracy 71.875 %
# Ep 0 |  train loss: 15.770999908447266, train accuracy 56.25 %
# Ep 0 |  train loss: 12.33899974822998, train accuracy 75.0 %
# Ep 0 |  train loss: 13.942999839782715, train accuracy 71.875 %
# Ep 0 |  train loss: 12.425999641418457, train accuracy 75.0 %
# Ep 0 |  train loss: 13.107000350952148, train accuracy 75.0 %
# Ep 0 |  train loss: 12.043000221252441, train accuracy 71.875 %
# Ep 0 |  train loss: 13.673999786376953, train accuracy 68.75 %
# Ep 0 |  train loss: 13.519000053405762, train accuracy 65.625 %
# Ep 0 |  train loss: 14.14799976348877, train accuracy 68.75 %
# Ep 0 |  train loss: 11.821999549865723, train accuracy 84.375 %
# Ep 0 |  train loss: 11.21399974822998, train accuracy 75.0 %
# Ep 0 |  train loss: 16.08099937438965, train accuracy 56.25 %
# Ep 0 |  train loss: 11.175000190734863, train accuracy 87.5 %
# Ep 0 |  train loss: 13.210000038146973, train accuracy 71.875 %
# Ep 0 |  train loss: 13.32800006866455, train accuracy 75.0 %
# Ep 0 |  train loss: 12.223999977111816, train accuracy 78.125 %
# Ep 0 |  train loss: 13.76200008392334, train accuracy 71.875 %
# Ep 0 |  train loss: 13.277999877929688, train accuracy 71.875 %
# Ep 0 |  train loss: 12.244999885559082, train accuracy 78.125 %
# Ep 0 |  train loss: 12.835000038146973, train accuracy 78.125 %
# Ep 0 |  train loss: 14.956000328063965, train accuracy 56.25 %
# Ep 0 |  train loss: 13.102999687194824, train accuracy 81.25 %
# Ep 0 |  train loss: 14.25, train accuracy 59.375 %
# Ep 0 |  train loss: 13.23900032043457, train accuracy 75.0 %
# Ep 0 |  train loss: 13.281000137329102, train accuracy 71.875 %
# Ep 0 |  train loss: 11.428999900817871, train accuracy 75.0 %
# Ep 0 |  train loss: 14.54699993133545, train accuracy 65.625 %
# Ep 0 |  train loss: 13.45199966430664, train accuracy 71.875 %
# Ep 0 |  train loss: 12.473999977111816, train accuracy 71.875 %
# Ep 0 |  train loss: 13.918999671936035, train accuracy 65.625 %
# Ep 0 |  train loss: 13.852999687194824, train accuracy 68.75 %
# Ep 0 |  train loss: 12.612000465393066, train accuracy 81.25 %
# Ep 0 |  train loss: 11.286999702453613, train accuracy 78.125 %
# Ep 0 |  train loss: 13.526000022888184, train accuracy 71.875 %
# Ep 0 |  train loss: 12.689000129699707, train accuracy 71.875 %
# Ep 0 |  train loss: 12.543999671936035, train accuracy 75.0 %
# Ep 0 |  train loss: 14.704000473022461, train accuracy 59.375 %
# Ep 0 |  train loss: 16.219999313354492, train accuracy 43.75 %
# Ep 0 |  train loss: 13.348999977111816, train accuracy 78.125 %
# Ep 0 |  train loss: 11.822999954223633, train accuracy 81.25 %
# Ep 0 |  train loss: 12.17300033569336, train accuracy 71.875 %
# Ep 0 |  train loss: 14.100000381469727, train accuracy 62.5 %
# Ep 0 |  train loss: 11.479999542236328, train accuracy 81.25 %
# Ep 0 |  train loss: 13.496000289916992, train accuracy 68.75 %
# Ep 0 |  train loss: 13.36400032043457, train accuracy 68.75 %
# Ep 0 |  train loss: 13.418999671936035, train accuracy 65.625 %
# Ep 0 |  train loss: 11.38599967956543, train accuracy 81.25 %
# Ep 0 |  train loss: 14.628000259399414, train accuracy 56.25 %
# Ep 0 |  train loss: 13.51099967956543, train accuracy 68.75 %
# Ep 0 |  train loss: 13.781999588012695, train accuracy 68.75 %
# Ep 0 |  train loss: 11.812000274658203, train accuracy 68.75 %
# Ep 0 |  train loss: 12.645000457763672, train accuracy 68.75 %
# Ep 0 |  train loss: 11.352999687194824, train accuracy 84.375 %
# Ep 0 |  train loss: 14.04800033569336, train accuracy 78.125 %
# Ep 0 |  train loss: 12.206000328063965, train accuracy 81.25 %
# Ep 0 |  train loss: 11.97700023651123, train accuracy 78.125 %
# Ep 0 |  train loss: 11.779999732971191, train accuracy 84.375 %
# Ep 0 |  train loss: 13.638999938964844, train accuracy 68.75 %
# Ep 0 |  train loss: 14.654000282287598, train accuracy 65.625 %
# Ep 0 |  train loss: 11.144000053405762, train accuracy 87.5 %
# Ep 0 |  train loss: 13.87600040435791, train accuracy 53.125 %
# Ep 0 |  train loss: 14.107999801635742, train accuracy 65.625 %
# Ep 0 |  train loss: 12.305999755859375, train accuracy 84.375 %
# Ep 0 |  train loss: 12.147000312805176, train accuracy 71.875 %
# Ep 0 |  train loss: 10.267999649047852, train accuracy 87.5 %
# Ep 0 |  train loss: 13.706999778747559, train accuracy 65.625 %
# Ep 0 |  train loss: 11.133000373840332, train accuracy 81.25 %
# Ep 0 |  train loss: 13.145000457763672, train accuracy 84.375 %
# Ep 0 |  train loss: 12.564000129699707, train accuracy 68.75 %
# Ep 0 |  train loss: 11.883999824523926, train accuracy 68.75 %
# Ep 0 |  train loss: 11.383000373840332, train accuracy 75.0 %
# Ep 0 |  train loss: 12.255000114440918, train accuracy 78.125 %
# Ep 0 |  train loss: 12.435999870300293, train accuracy 62.5 %
# Ep 0 |  train loss: 12.107000350952148, train accuracy 78.125 %
# Ep 0 |  train loss: 12.126999855041504, train accuracy 78.125 %
# Ep 0 |  train loss: 11.765999794006348, train accuracy 84.375 %
# Ep 0 |  train loss: 15.241999626159668, train accuracy 68.75 %
# Ep 0 |  train loss: 12.458000183105469, train accuracy 65.625 %
# Ep 0 |  train loss: 16.326000213623047, train accuracy 56.25 %
# Ep 0 |  train loss: 12.116000175476074, train accuracy 59.375 %
# Ep 0 |  train loss: 12.142999649047852, train accuracy 81.25 %
# Ep 0 |  train loss: 11.786999702453613, train accuracy 75.0 %
# Ep 0 |  train loss: 12.654999732971191, train accuracy 75.0 %
# Ep 0 |  train loss: 12.005999565124512, train accuracy 68.75 %
# Ep 0 |  train loss: 11.833999633789062, train accuracy 81.25 %
# Ep 0 |  train loss: 13.876999855041504, train accuracy 65.625 %
# Ep 0 |  train loss: 13.375, train accuracy 68.75 %
# Ep 0 |  train loss: 13.359000205993652, train accuracy 62.5 %
# Ep 0 |  train loss: 12.331000328063965, train accuracy 65.625 %
# Ep 0 |  train loss: 14.552000045776367, train accuracy 59.375 %
# Ep 0 |  train loss: 9.765999794006348, train accuracy 87.5 %
# Ep 0 |  train loss: 13.729000091552734, train accuracy 65.625 %
# Ep 0 |  train loss: 10.42300033569336, train accuracy 84.375 %
# Ep 0 |  train loss: 14.505999565124512, train accuracy 71.875 %
# Ep 0 |  train loss: 11.552000045776367, train accuracy 78.125 %
# Ep 0 |  train loss: 12.465999603271484, train accuracy 75.0 %
# Ep 0 |  train loss: 13.098999977111816, train accuracy 68.75 %
# Ep 0 |  train loss: 11.010000228881836, train accuracy 84.375 %
# Ep 0 |  train loss: 13.229000091552734, train accuracy 75.0 %
# Ep 0 |  train loss: 13.458000183105469, train accuracy 75.0 %
# Ep 0 |  train loss: 12.991000175476074, train accuracy 75.0 %
# Ep 0 |  train loss: 12.456999778747559, train accuracy 75.0 %
# Ep 0 |  train loss: 13.53499984741211, train accuracy 65.625 %
# Ep 0 |  train loss: 13.039999961853027, train accuracy 71.875 %
# Ep 0 |  train loss: 14.708000183105469, train accuracy 62.5 %
# Ep 0 |  train loss: 12.086000442504883, train accuracy 87.5 %
# Ep 0 |  train loss: 11.571000099182129, train accuracy 81.25 %
# Ep 0 |  train loss: 12.109000205993652, train accuracy 65.625 %
# Ep 0 |  train loss: 12.543000221252441, train accuracy 71.875 %
# Ep 0 |  train loss: 10.548999786376953, train accuracy 84.375 %
# Ep 0 |  train loss: 11.487000465393066, train accuracy 71.875 %
# Ep 0 |  train loss: 13.840999603271484, train accuracy 62.5 %
# Ep 0 |  train loss: 11.154000282287598, train accuracy 78.125 %
# Ep 0 |  train loss: 11.710000038146973, train accuracy 78.125 %
# Ep 0 |  train loss: 12.227999687194824, train accuracy 75.0 %
# Ep 0 |  train loss: 12.173999786376953, train accuracy 81.25 %
# Ep 0 |  train loss: 13.020000457763672, train accuracy 68.75 %
# Ep 0 |  train loss: 13.170999526977539, train accuracy 62.5 %
# Ep 0 |  train loss: 14.050000190734863, train accuracy 65.625 %
# Ep 0 |  train loss: 12.902000427246094, train accuracy 75.0 %
# Ep 0 |  train loss: 12.333999633789062, train accuracy 71.875 %
# Ep 0 |  train loss: 14.717000007629395, train accuracy 62.5 %
# Ep 0 |  train loss: 12.854999542236328, train accuracy 71.875 %
# Ep 0 |  train loss: 11.454000473022461, train accuracy 75.0 %
# Ep 0 |  train loss: 13.128999710083008, train accuracy 68.75 %
# Ep 0 |  train loss: 14.4399995803833, train accuracy 68.75 %
# Ep 0 |  train loss: 12.788000106811523, train accuracy 71.875 %
# Ep 0 |  train loss: 10.628999710083008, train accuracy 78.125 %
# Ep 0 |  train loss: 12.119999885559082, train accuracy 81.25 %
# Ep 0 |  train loss: 13.977999687194824, train accuracy 62.5 %
# Ep 0 |  train loss: 11.97599983215332, train accuracy 75.0 %
# Ep 0 |  train loss: 11.109000205993652, train accuracy 81.25 %
# Ep 0 |  train loss: 12.670999526977539, train accuracy 68.75 %
# Ep 0 |  train loss: 13.829000473022461, train accuracy 75.0 %
# Ep 0 |  train loss: 11.840999603271484, train accuracy 78.125 %
# Ep 0 |  train loss: 12.156999588012695, train accuracy 75.0 %
# Ep 0 |  train loss: 11.539999961853027, train accuracy 75.0 %
# Ep 0 |  train loss: 11.875, train accuracy 75.0 %
# Ep 0 |  train loss: 14.564000129699707, train accuracy 65.625 %
# Ep 0 |  train loss: 11.689000129699707, train accuracy 81.25 %
# Ep 0 |  train loss: 14.769000053405762, train accuracy 68.75 %
# Ep 0 |  train loss: 12.289999961853027, train accuracy 75.0 %
# Ep 0 |  train loss: 13.128000259399414, train accuracy 68.75 %
# Ep 0 |  train loss: 10.98900032043457, train accuracy 84.375 %
# Ep 0 |  train loss: 13.645999908447266, train accuracy 71.875 %
# Ep 0 |  train loss: 11.14799976348877, train accuracy 81.25 %
# Ep 0 |  train loss: 11.220000267028809, train accuracy 71.875 %
# Ep 0 |  train loss: 12.321000099182129, train accuracy 75.0 %
# Ep 0 |  train loss: 10.163000106811523, train accuracy 84.375 %
# Ep 0 |  train loss: 12.652999877929688, train accuracy 78.125 %
# Ep 0 |  train loss: 12.930999755859375, train accuracy 68.75 %
# Ep 0 |  train loss: 12.092000007629395, train accuracy 65.625 %
# Ep 0 |  train loss: 12.972000122070312, train accuracy 78.125 %
# Ep 0 |  train loss: 13.131999969482422, train accuracy 68.75 %
# Ep 0 |  train loss: 12.420999526977539, train accuracy 71.875 %
# Ep 0 |  train loss: 10.277000427246094, train accuracy 90.625 %
# Ep 0 |  train loss: 11.29800033569336, train accuracy 78.125 %
# Ep 0 |  train loss: 11.71399974822998, train accuracy 75.0 %
# Ep 0 |  train loss: 15.015999794006348, train accuracy 56.25 %
# Ep 0 |  train loss: 10.935999870300293, train accuracy 84.375 %
# Ep 0 |  train loss: 11.777000427246094, train accuracy 81.25 %
# Ep 0 |  train loss: 12.0600004196167, train accuracy 78.125 %
# Ep 0 |  train loss: 13.781000137329102, train accuracy 62.5 %
# Ep 0 |  train loss: 10.711999893188477, train accuracy 90.625 %
# Ep 0 |  train loss: 11.847999572753906, train accuracy 78.125 %
# Ep 0 |  train loss: 12.482999801635742, train accuracy 78.125 %
# Ep 0 |  train loss: 14.03600025177002, train accuracy 68.75 %
# Ep 0 |  train loss: 13.630000114440918, train accuracy 71.875 %
# Ep 0 |  train loss: 12.029000282287598, train accuracy 81.25 %
# Ep 0 |  train loss: 10.652000427246094, train accuracy 75.0 %
# Ep 0 |  train loss: 13.61400032043457, train accuracy 62.5 %
# Ep 0 |  train loss: 13.73799991607666, train accuracy 68.75 %
# Ep 0 |  train loss: 13.043000221252441, train accuracy 71.875 %
# Ep 0 |  train loss: 12.354999542236328, train accuracy 68.75 %
# Ep 0 |  train loss: 10.61400032043457, train accuracy 78.125 %
# Ep 0 |  train loss: 12.506999969482422, train accuracy 65.625 %
# Ep 0 |  train loss: 10.684000015258789, train accuracy 81.25 %
# Ep 0 |  train loss: 12.869000434875488, train accuracy 71.875 %
# Ep 0 |  train loss: 15.289999961853027, train accuracy 59.375 %
# Ep 0 |  train loss: 11.932000160217285, train accuracy 75.0 %
# Ep 0 |  train loss: 13.267999649047852, train accuracy 59.375 %
# Ep 0 |  train loss: 13.911999702453613, train accuracy 65.625 %
# Ep 0 |  train loss: 12.666000366210938, train accuracy 68.75 %
# Ep 0 |  train loss: 12.854000091552734, train accuracy 65.625 %
# Ep 0 |  train loss: 12.348999977111816, train accuracy 78.125 %
# Ep 0 |  train loss: 11.211000442504883, train accuracy 84.375 %
# Ep 0 |  train loss: 12.08899974822998, train accuracy 75.0 %
# Ep 0 |  train loss: 10.894000053405762, train accuracy 90.625 %
# Ep 0 |  train loss: 14.42300033569336, train accuracy 62.5 %
# Ep 0 |  train loss: 13.317000389099121, train accuracy 65.625 %
# Ep 0 |  train loss: 13.57800006866455, train accuracy 81.25 %
# Ep 0 |  train loss: 12.10099983215332, train accuracy 78.125 %
# Ep 0 |  train loss: 10.71500015258789, train accuracy 84.375 %
# Ep 0 |  train loss: 11.866000175476074, train accuracy 68.75 %
# Ep 0 |  train loss: 12.319999694824219, train accuracy 75.0 %
# Ep 0 |  train loss: 12.086999893188477, train accuracy 68.75 %
# Ep 0 |  train loss: 12.29699993133545, train accuracy 75.0 %
# Ep 0 |  train loss: 11.76099967956543, train accuracy 81.25 %
# Ep 0 |  train loss: 13.484000205993652, train accuracy 71.875 %
# Ep 0 |  train loss: 14.003000259399414, train accuracy 62.5 %
# Ep 0 |  train loss: 12.279000282287598, train accuracy 75.0 %
# Ep 0 |  train loss: 12.633000373840332, train accuracy 68.75 %
# Ep 0 |  train loss: 12.008000373840332, train accuracy 90.625 %
# Ep 0 |  train loss: 13.102999687194824, train accuracy 78.125 %
# Ep 0 |  train loss: 12.395000457763672, train accuracy 75.0 %
# Ep 0 |  train loss: 13.72599983215332, train accuracy 68.75 %
# Ep 0 |  train loss: 12.97700023651123, train accuracy 71.875 %
# Ep 0 |  train loss: 12.918000221252441, train accuracy 65.625 %
# Ep 0 |  train loss: 13.12399959564209, train accuracy 65.625 %
# Ep 0 |  train loss: 11.854000091552734, train accuracy 75.0 %
# Ep 0 |  train loss: 12.472999572753906, train accuracy 71.875 %
# Ep 0 |  train loss: 11.968999862670898, train accuracy 75.0 %
# Ep 0 |  train loss: 11.244000434875488, train accuracy 78.125 %
# Ep 0 |  train loss: 11.654999732971191, train accuracy 81.25 %
# Ep 0 |  train loss: 10.121000289916992, train accuracy 87.5 %
# Ep 0 |  train loss: 11.262999534606934, train accuracy 75.0 %
# Ep 0 |  train loss: 10.986000061035156, train accuracy 81.25 %
# Ep 0 |  train loss: 10.618000030517578, train accuracy 87.5 %
# Ep 0 |  train loss: 10.776000022888184, train accuracy 87.5 %
# Ep 0 |  train loss: 12.178999900817871, train accuracy 84.375 %
# Ep 0 |  train loss: 11.965999603271484, train accuracy 75.0 %
# Ep 0 |  train loss: 14.52400016784668, train accuracy 62.5 %
# Ep 0 |  train loss: 12.550000190734863, train accuracy 65.625 %
# Ep 0 |  train loss: 11.17300033569336, train accuracy 75.0 %
# Ep 0 |  train loss: 13.086999893188477, train accuracy 71.875 %
# Ep 0 |  train loss: 10.552000045776367, train accuracy 87.5 %
# Ep 0 |  train loss: 10.404000282287598, train accuracy 87.5 %
# Ep 0 |  train loss: 12.552000045776367, train accuracy 78.125 %
# Ep 0 |  train loss: 11.01200008392334, train accuracy 78.125 %
# Ep 0 |  train loss: 13.149999618530273, train accuracy 65.625 %
# Ep 0 |  train loss: 13.508000373840332, train accuracy 71.875 %
# Ep 0 |  train loss: 11.534000396728516, train accuracy 68.75 %
# Ep 0 |  train loss: 12.680999755859375, train accuracy 68.75 %
# Ep 0 |  train loss: 12.633999824523926, train accuracy 71.875 %
# Ep 0 |  train loss: 11.38700008392334, train accuracy 75.0 %
# Ep 0 |  train loss: 10.76200008392334, train accuracy 84.375 %
# Ep 0 |  train loss: 11.333999633789062, train accuracy 75.0 %
# Ep 0 |  train loss: 12.739999771118164, train accuracy 68.75 %
# Ep 0 |  train loss: 11.539999961853027, train accuracy 84.375 %
# Ep 0 |  train loss: 10.87600040435791, train accuracy 81.25 %
# Ep 0 |  train loss: 13.272000312805176, train accuracy 71.875 %
# Ep 0 |  train loss: 11.29800033569336, train accuracy 78.125 %
# Ep 0 |  train loss: 10.998000144958496, train accuracy 90.625 %
# Ep 0 |  train loss: 10.230999946594238, train accuracy 75.0 %
# Ep 0 |  train loss: 15.427000045776367, train accuracy 59.375 %
# Ep 0 |  train loss: 10.609000205993652, train accuracy 84.375 %
# Ep 0 |  train loss: 11.493000030517578, train accuracy 81.25 %
# Ep 0 |  train loss: 14.29800033569336, train accuracy 62.5 %
# Ep 0 |  train loss: 11.534000396728516, train accuracy 71.875 %
# Ep 0 |  train loss: 14.102999687194824, train accuracy 62.5 %
# Ep 0 |  train loss: 11.300000190734863, train accuracy 81.25 %
# Ep 0 |  train loss: 10.508000373840332, train accuracy 75.0 %
# Ep 0 |  train loss: 15.418000221252441, train accuracy 53.125 %
# Ep 0 |  train loss: 11.04699993133545, train accuracy 75.0 %
# Ep 0 |  train loss: 10.677000045776367, train accuracy 84.375 %
# Ep 0 |  train loss: 12.819000244140625, train accuracy 68.75 %
# Ep 0 |  train loss: 11.696999549865723, train accuracy 78.125 %
# Ep 0 |  train loss: 12.329000473022461, train accuracy 71.875 %
# Ep 0 |  train loss: 11.642000198364258, train accuracy 71.875 %
# Ep 0 |  train loss: 11.564000129699707, train accuracy 75.0 %
# Ep 0 |  train loss: 12.11400032043457, train accuracy 75.0 %
# Ep 0 |  train loss: 13.758000373840332, train accuracy 65.625 %
# Ep 0 |  train loss: 11.947999954223633, train accuracy 78.125 %
# Ep 0 |  train loss: 9.552000045776367, train accuracy 84.375 %
# Ep 0 |  train loss: 11.798999786376953, train accuracy 75.0 %
# Ep 0 |  train loss: 12.581999778747559, train accuracy 65.625 %
# Ep 0 |  train loss: 13.666999816894531, train accuracy 75.0 %
# Ep 0 |  train loss: 10.54800033569336, train accuracy 93.75 %
# Ep 0 |  train loss: 10.92199993133545, train accuracy 81.25 %
# Ep 0 |  train loss: 11.135000228881836, train accuracy 84.375 %
# Ep 0 |  train loss: 12.142999649047852, train accuracy 62.5 %
# Ep 0 |  train loss: 15.864999771118164, train accuracy 62.5 %
# Ep 0 |  train loss: 10.842000007629395, train accuracy 75.0 %
# Ep 0 |  train loss: 11.335000038146973, train accuracy 81.25 %
# Ep 0 |  train loss: 11.696999549865723, train accuracy 78.125 %
# Ep 0 |  train loss: 11.647000312805176, train accuracy 78.125 %
# Ep 0 |  train loss: 11.128999710083008, train accuracy 71.875 %
# Ep 0 |  train loss: 12.260000228881836, train accuracy 65.625 %
# Ep 0 |  train loss: 16.22599983215332, train accuracy 56.25 %
# Ep 0 |  train loss: 10.645000457763672, train accuracy 78.125 %
# Ep 0 |  train loss: 11.1899995803833, train accuracy 84.375 %
# Ep 0 |  train loss: 12.0, train accuracy 75.0 %
# Ep 0 |  train loss: 12.595000267028809, train accuracy 65.625 %
# Ep 0 |  train loss: 13.496000289916992, train accuracy 71.875 %
# Ep 0 |  train loss: 9.23799991607666, train accuracy 84.375 %
# Ep 0 |  train loss: 11.621999740600586, train accuracy 78.125 %
# Ep 0 |  train loss: 11.47700023651123, train accuracy 81.25 %
# Ep 0 |  train loss: 11.104999542236328, train accuracy 75.0 %
# Ep 0 |  train loss: 9.994999885559082, train accuracy 90.625 %
# Ep 0 |  train loss: 13.185999870300293, train accuracy 65.625 %
# Ep 0 |  train loss: 14.220000267028809, train accuracy 68.75 %
# Ep 0 |  train loss: 11.916999816894531, train accuracy 75.0 %
# Ep 0 |  train loss: 12.08899974822998, train accuracy 78.125 %
# Ep 0 |  train loss: 12.204000473022461, train accuracy 84.375 %
# Ep 0 |  train loss: 13.22700023651123, train accuracy 65.625 %
# Ep 0 |  train loss: 12.237000465393066, train accuracy 78.125 %
# ...
# Ep 0 |  train loss: 8.876999855041504, train accuracy 84.375 %
# Ep 0 |  train loss: 10.89799976348877, train accuracy 78.125 %
# Ep 0 |  train loss: 10.54699993133545, train accuracy 87.5 %
# Ep 0 |  train loss: 11.503000259399414, train accuracy 71.875 %
# Ep 0 |  train loss: 8.873000144958496, train accuracy 87.5 %
# Ep 0 |  train loss: 9.140999794006348, train accuracy 84.375 %
# Ep 0 |  train loss: 11.038000106811523, train accuracy 71.875 %
# Ep 0 |  train loss: 13.119999885559082, train accuracy 62.5 %
# Ep 0 |  train loss: 10.944999694824219, train accuracy 81.25 %
# Ep 0 |  train loss: 12.767000198364258, train accuracy 71.875 %
# Ep 0 |  train loss: 10.48900032043457, train accuracy 75.0 %
# Ep 0 |  train loss: 9.111000061035156, train accuracy 78.125 %
# Ep 0 |  train loss: 12.54699993133545, train accuracy 71.875 %
# Ep 0 |  train loss: 9.956000328063965, train accuracy 84.375 %
# Ep 0 |  train loss: 11.845000267028809, train accuracy 71.875 %
# Ep 0 |  train loss: 11.77400016784668, train accuracy 71.875 %
# Ep 0 |  train loss: 10.85200023651123, train accuracy 81.25 %
# Ep 0 |  train loss: 7.598999977111816, train accuracy 87.5 %
# Ep 0 |  train loss: 9.119000434875488, train accuracy 87.5 %
# Ep 0 |  train loss: 9.159000396728516, train accuracy 81.25 %
# Ep 0 |  train loss: 11.48799991607666, train accuracy 78.125 %
# Ep 0 |  train loss: 11.545000076293945, train accuracy 68.75 %
# Ep 0 |  train loss: 12.343999862670898, train accuracy 65.625 %
# Ep 0 |  train loss: 11.993000030517578, train accuracy 71.875 %
# Ep 0 |  train loss: 12.888999938964844, train accuracy 71.875 %
# Ep 0 |  train loss: 8.329000473022461, train accuracy 87.5 %
# Ep 0 |  train loss: 10.20300006866455, train accuracy 78.125 %
# Ep 0 |  train loss: 10.942999839782715, train accuracy 75.0 %
# Ep 0 |  train loss: 14.975000381469727, train accuracy 59.375 %
# Ep 0 |  train loss: 12.961999893188477, train accuracy 68.75 %
# Ep 0 |  train loss: 9.213000297546387, train accuracy 84.375 %
# Ep 0 |  train loss: 9.53600025177002, train accuracy 84.375 %
# Ep 0 |  train loss: 9.309000015258789, train accuracy 84.375 %
# Ep 0 |  train loss: 10.972999572753906, train accuracy 71.875 %
# Ep 0 |  train loss: 11.571999549865723, train accuracy 84.375 %
# Ep 0 |  train loss: 10.20300006866455, train accuracy 78.125 %
# Ep 0 |  train loss: 13.586999893188477, train accuracy 68.75 %
# Ep 0 |  train loss: 8.156999588012695, train accuracy 90.625 %
# Ep 0 |  train loss: 10.41100025177002, train accuracy 81.25 %
# Ep 0 |  train loss: 11.428000450134277, train accuracy 75.0 %
# Ep 0 |  train loss: 11.456000328063965, train accuracy 71.875 %
# Ep 0 |  train loss: 12.177000045776367, train accuracy 75.0 %
# Ep 0 |  train loss: 9.954000473022461, train accuracy 87.5 %
# Ep 0 |  train loss: 9.430999755859375, train accuracy 87.5 %
# Ep 0 |  train loss: 12.583999633789062, train accuracy 71.875 %
# Ep 0 |  train loss: 12.89799976348877, train accuracy 65.625 %
# Ep 0 |  train loss: 12.717000007629395, train accuracy 71.875 %
# Ep 0 |  train loss: 10.623000144958496, train accuracy 84.375 %
# Ep 0 |  train loss: 9.812999725341797, train accuracy 78.125 %
# Ep 0 |  train loss: 10.640000343322754, train accuracy 84.375 %
# Ep 0 |  train loss: 10.45300006866455, train accuracy 84.375 %
# Ep 0 |  train loss: 14.930000305175781, train accuracy 65.625 %
# Ep 0 |  train loss: 12.972999572753906, train accuracy 65.625 %
# Ep 0 |  train loss: 10.46399974822998, train accuracy 75.0 %
# Ep 0 |  train loss: 9.704000473022461, train accuracy 81.25 %
# Ep 0 |  train loss: 9.269000053405762, train accuracy 84.375 %
# Ep 0 |  train loss: 11.154000282287598, train accuracy 75.0 %
# Ep 0 |  train loss: 9.916000366210938, train accuracy 81.25 %
# Ep 0 |  train loss: 9.210000038146973, train accuracy 78.125 %
# Ep 0 |  train loss: 13.640000343322754, train accuracy 65.625 %
# Ep 0 |  train loss: 12.178999900817871, train accuracy 75.0 %
# Ep 0 |  train loss: 12.854000091552734, train accuracy 59.375 %
# Ep 0 |  train loss: 13.387999534606934, train accuracy 65.625 %
# Ep 0 |  train loss: 9.84000015258789, train accuracy 81.25 %
# Ep 0 |  train loss: 9.949000358581543, train accuracy 81.25 %
# Ep 0 |  train loss: 10.3149995803833, train accuracy 81.25 %
# Ep 0 |  train loss: 11.006999969482422, train accuracy 78.125 %
# Ep 0 |  train loss: 10.125, train accuracy 81.25 %
# Ep 0 |  train loss: 10.76200008392334, train accuracy 75.0 %
# Ep 0 |  train loss: 13.359000205993652, train accuracy 59.375 %
# Ep 0 |  train loss: 10.125, train accuracy 84.375 %
# Ep 0 |  train loss: 10.579000473022461, train accuracy 81.25 %
# Ep 0 |  train loss: 10.585000038146973, train accuracy 84.375 %
# Ep 0 |  train loss: 11.052000045776367, train accuracy 75.0 %
# Ep 0 |  train loss: 10.661999702453613, train accuracy 78.125 %
# Ep 0 |  train loss: 8.043999671936035, train accuracy 90.625 %
# Ep 0 |  train loss: 9.036999702453613, train accuracy 90.625 %
# Ep 0 |  train loss: 10.182999610900879, train accuracy 84.375 %
# Ep 0 |  train loss: 7.978000164031982, train accuracy 90.625 %
# Ep 0 |  train loss: 12.946000099182129, train accuracy 68.75 %
# Ep 0 |  train loss: 10.513999938964844, train accuracy 81.25 %
# Ep 0 |  train loss: 13.47700023651123, train accuracy 71.875 %
# Ep 0 |  train loss: 8.340999603271484, train accuracy 87.5 %
# Ep 0 |  train loss: 10.263999938964844, train accuracy 84.375 %
# Ep 0 |  train loss: 9.829000473022461, train accuracy 84.375 %
# Ep 0 |  train loss: 9.489999771118164, train accuracy 87.5 %
# Ep 0 |  train loss: 8.262999534606934, train accuracy 93.75 %
# Ep 0 |  train loss: 9.902999877929688, train accuracy 71.875 %
# Ep 0 |  train loss: 10.369999885559082, train accuracy 78.125 %
# Ep 0 |  train loss: 12.223999977111816, train accuracy 65.625 %
# Ep 0 |  train loss: 8.015999794006348, train accuracy 84.375 %
# Ep 0 |  train loss: 10.413999557495117, train accuracy 84.375 %
# Ep 0 |  train loss: 9.937999725341797, train accuracy 81.25 %
# Ep 0 |  train loss: 11.942999839782715, train accuracy 75.0 %
# Ep 0 |  train loss: 11.08899974822998, train accuracy 81.25 %
# Ep 0 |  train loss: 10.472000122070312, train accuracy 75.0 %
# Ep 0 |  train loss: 9.034000396728516, train accuracy 87.5 %
# Ep 0 |  train loss: 9.295999526977539, train accuracy 87.5 %
# Ep 0 |  train loss: 9.420999526977539, train accuracy 87.5 %
# Ep 0 |  train loss: 11.053999900817871, train accuracy 78.125 %
# Ep 0 |  train loss: 9.347999572753906, train accuracy 87.5 %
# Ep 0 |  train loss: 10.878000259399414, train accuracy 75.0 %
# Ep 0 |  train loss: 11.902000427246094, train accuracy 75.0 %
# Ep 0 |  train loss: 8.531000137329102, train accuracy 87.5 %
# Ep 0 |  train loss: 10.847999572753906, train accuracy 78.125 %
# Ep 0 |  train loss: 9.6850004196167, train accuracy 75.0 %
# Ep 0 |  train loss: 10.043000221252441, train accuracy 81.25 %
# Ep 0 |  train loss: 11.26099967956543, train accuracy 68.75 %
# Ep 0 |  train loss: 11.592000007629395, train accuracy 75.0 %
# Ep 0 |  train loss: 14.744999885559082, train accuracy 62.5 %
# Ep 0 |  train loss: 10.359000205993652, train accuracy 81.25 %
# Ep 0 |  train loss: 10.562000274658203, train accuracy 78.125 %
# Ep 0 |  train loss: 11.638999938964844, train accuracy 75.0 %
# Ep 0 |  train loss: 9.635000228881836, train accuracy 84.375 %
# Ep 0 |  train loss: 9.425999641418457, train accuracy 78.125 %
# Ep 0 |  train loss: 11.340999603271484, train accuracy 78.125 %
# Ep 0 |  train loss: 12.470000267028809, train accuracy 65.625 %
# Ep 0 |  train loss: 10.305000305175781, train accuracy 78.125 %
# Ep 0 |  train loss: 9.550000190734863, train accuracy 78.125 %
# Ep 0 |  train loss: 11.413000106811523, train accuracy 84.375 %
# Ep 0 |  train loss: 11.54699993133545, train accuracy 71.875 %
# Ep 0 |  train loss: 11.782999992370605, train accuracy 75.0 %
# Ep 0 |  train loss: 9.593000411987305, train accuracy 78.125 %
# Ep 0 |  train loss: 10.57800006866455, train accuracy 78.125 %
# Ep 0 |  train loss: 10.3149995803833, train accuracy 75.0 %
# Ep 0 |  train loss: 8.87399959564209, train accuracy 87.5 %
# Ep 0 |  train loss: 9.970000267028809, train accuracy 78.125 %
# Ep 0 |  train loss: 13.329000473022461, train accuracy 75.0 %
# Ep 0 |  train loss: 11.404000282287598, train accuracy 71.875 %
# Ep 0 |  train loss: 9.189000129699707, train accuracy 93.75 %
# Ep 0 |  train loss: 9.40999984741211, train accuracy 90.625 %
# Ep 0 |  train loss: 10.204000473022461, train accuracy 78.125 %
# Ep 0 |  train loss: 9.723999977111816, train accuracy 84.375 %
# Ep 0 |  train loss: 13.053999900817871, train accuracy 71.875 %
# Ep 0 |  train loss: 10.633000373840332, train accuracy 78.125 %
# Ep 0 |  train loss: 10.484999656677246, train accuracy 90.625 %
# Ep 0 |  train loss: 10.906000137329102, train accuracy 81.25 %
# Ep 0 |  train loss: 12.380000114440918, train accuracy 68.75 %
# Ep 0 |  train loss: 10.17300033569336, train accuracy 78.125 %
# Ep 0 |  train loss: 8.13599967956543, train accuracy 81.25 %
# Ep 0 |  train loss: 11.725000381469727, train accuracy 71.875 %
# Ep 0 |  train loss: 12.37399959564209, train accuracy 68.75 %
# Ep 0 |  train loss: 8.04699993133545, train accuracy 87.5 %
# Ep 0 |  train loss: 10.553999900817871, train accuracy 78.125 %
# Ep 0 |  train loss: 9.993000030517578, train accuracy 84.375 %
# Ep 0 |  train loss: 12.342000007629395, train accuracy 65.625 %
# Ep 0 |  train loss: 10.461000442504883, train accuracy 78.125 %
# Ep 0 |  train loss: 9.133999824523926, train accuracy 84.375 %
# Ep 0 |  train loss: 10.199000358581543, train accuracy 90.625 %
# Ep 0 |  train loss: 10.505000114440918, train accuracy 84.375 %
# Ep 0 |  train loss: 10.439000129699707, train accuracy 78.125 %
# Ep 0 |  train loss: 9.229000091552734, train accuracy 84.375 %
# Ep 0 |  train loss: 10.704999923706055, train accuracy 84.375 %
# Ep 0 |  train loss: 7.611999988555908, train accuracy 90.625 %
# Ep 0 |  train loss: 10.498000144958496, train accuracy 81.25 %
# Ep 0 |  train loss: 8.350000381469727, train accuracy 87.5 %
# Ep 0 |  train loss: 11.880999565124512, train accuracy 75.0 %
# Ep 0 |  train loss: 11.368000030517578, train accuracy 75.0 %
# Ep 0 |  train loss: 9.868000030517578, train accuracy 84.375 %
# Ep 0 |  train loss: 11.14799976348877, train accuracy 78.125 %
# Ep 0 |  train loss: 8.536999702453613, train accuracy 90.625 %
# Ep 0 |  train loss: 8.619999885559082, train accuracy 84.375 %
# Ep 0 |  train loss: 11.293999671936035, train accuracy 78.125 %
# Ep 0 |  train loss: 11.140999794006348, train accuracy 75.0 %
# Ep 0 |  train loss: 11.748000144958496, train accuracy 71.875 %
# Ep 0 |  train loss: 11.902999877929688, train accuracy 65.625 %
# Ep 0 |  train loss: 16.049999237060547, train accuracy 59.375 %
# Ep 0 |  train loss: 10.435999870300293, train accuracy 81.25 %
# Ep 0 |  train loss: 10.053000450134277, train accuracy 84.375 %
# Ep 0 |  train loss: 12.135000228881836, train accuracy 71.875 %
# Ep 0 |  train loss: 5.114999771118164, train accuracy 40.625 %
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-89be47f09aaf> in <module>
#       3 for epoch in range(10):
#       4
# ----> 5     for vectors, targets in trainloader:
#       6
#       7         # 1). Zero out previous gradients
#
# ~/miniconda3/envs/syfertext/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/miniconda3/envs/syfertext/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     383     def _next_data(self):
#     384         index = self._next_index()  # may raise StopIteration
# --> 385         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     386         if self._pin_memory:
#     387             data = _utils.pin_memory.pin_memory(data)
#
# ~/miniconda3/envs/syfertext/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/miniconda3/envs/syfertext/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# <ipython-input-14-c151597a2417> in __getitem__(self, index)
#      31
#      32         # Encrypte the target label
# ---> 33         label_enc = example['label'].fix_precision().share(bob,
#      34                                                            alice,
#      35                                                            crypto_provider = self.crypto_provider,
#
# ~/miniconda3/envs/syfertext/lib/python3.6/site-packages/syft/frameworks/torch/tensors/interpreters/native.py in fix_prec(self, storage, field_type, no_wrap, *args, **kwargs)
#     755
#     756         if self.is_wrapper:
# --> 757             self.child = self.child.fix_prec(*args, **kwargs)
#     758             if no_wrap:
#     759                 return self.child
#
# ~/miniconda3/envs/syfertext/lib/python3.6/site-packages/syft/generic/pointers/pointer_tensor.py in fix_prec(self, *args, **kwargs)
#     351         command = ("fix_prec", self, args, kwargs)
#     352
# --> 353         response = self.owner.send_command(self.location, command)
#     354
#     355         return response
#
# ~/miniconda3/envs/syfertext/lib/python3.6/site-packages/syft/workers/base.py in send_command(self, recipient, message, return_ids)
#     515         try:
#     516             ret_val = self.send_msg(
# --> 517                 Operation(cmd_name, cmd_owner, cmd_args, cmd_kwargs, return_ids), location=recipient
#     518             )
#     519         except ResponseSignatureError as e:
#
# ~/miniconda3/envs/syfertext/lib/python3.6/site-packages/syft/workers/base.py in send_msg(self, message, location)
#     280
#     281         # Step 2: send the message and wait for a response
# --> 282         bin_response = self._send_msg(bin_message, location)
#     283
#     284         # Step 3: deserialize the response
#
# ~/miniconda3/envs/syfertext/lib/python3.6/site-packages/syft/workers/virtual.py in _send_msg(self, message, location)
#      12             sleep(self.message_pending_time)
#      13
# ---> 14         return location._recv_msg(message)
#      15
#      16     def _recv_msg(self, message: bin) -> bin:
#
# ~/miniconda3/envs/syfertext/lib/python3.6/site-packages/syft/workers/virtual.py in _recv_msg(self, message)
#      15
#      16     def _recv_msg(self, message: bin) -> bin:
# ---> 17         return self.recv_msg(message)
#
# ~/miniconda3/envs/syfertext/lib/python3.6/site-packages/syft/workers/base.py in recv_msg(self, bin_message)
#     313
#     314         # Step 1: route message to appropriate function
# --> 315         response = self._message_router[type(msg)](msg.contents)
#     316
#     317         # Step 2: Serialize the message to simple python objects
#
# ~/miniconda3/envs/syfertext/lib/python3.6/site-packages/syft/workers/base.py in execute_command(self, message)
#     432             else:
#     433                 try:
# --> 434                     response = getattr(_self, command_name)(*args, **kwargs)
#     435                 except TypeError:
#     436                     # TODO Andrew thinks this is gross, please fix. Instead need to properly deserialize strings
#
# ~/miniconda3/envs/syfertext/lib/python3.6/site-packages/syft/frameworks/torch/tensors/interpreters/native.py in fix_prec(self, storage, field_type, no_wrap, *args, **kwargs)
#     755
#     756         if self.is_wrapper:
# --> 757             self.child = self.child.fix_prec(*args, **kwargs)
#     758             if no_wrap:
#     759                 return self.child
#
# AttributeError: 'FixedPrecisionTensor' object has no attribute 'fix_prec'

# %% [markdown]
# ### TODO:
#
# 1. **Create a pipe element to perform polarity cutoff:**
#
# ```
# word_polarity = pass # dict of the form word: polarity
# polarity_filter = PolarityFilter(data = word_polarity,
#                                  max_pol = 1.3,
#                                  min_pol = -1.3, # tokens whos polarity between [min_pol, max_pol]
#                                                  # will be tagged 'in_doc_vectors' = False
#                                  tag = 'in_doc_vector' # the tag in which to store the True of False result
#                                 )
#
# # create an element that computes a doc vector
# # only by considering the elements tagged as
# # sepcifified by 'tag'
# doc_vectorizer = DocVectorizer(tag = 'in_doc_vector')
#
# nlp.add_pipe(polarity_filter)
# nlp.add_pipe(doc_vectorizer)
# ```
#
# 2. **create a module in SyferText where the Dataset object for IMDB movie reviews can be imported:**
#
# (or DatasetIMDB can just return a list of sets, each is of the form [{'review': <string>, 'sentiment': int}, ...])
# and then we create the dataset object out of this
#
# ```
# from syfertext.datasets.imdb import DatasetIMDB
# from torch.utils.data import DataLoader
#
# # This loads the IMDB PyTorch Dataset object
# # it will download the dataset, load it locally
# # then sends it to the specified workers
# # we can specify the proportion each worker takes
# # of each of the classes. for instance
# # bob here takes 30% of positive examples from the
# # original dataset and 20% of its negative examples
# trainset = DatasetIMDB(bob, alice,
#                        dist = {'bob': {'pos' : 30, 'neg': 20},
#                                'alice': {'pos' 70, 'neg': 50}},
#                        mode = 'train'
#                        pipes = [polarity_filter, doc_vectorizer]
#                       )
#
# valset = DatasetIMDB(bob, alice,
#                      dist = {'bob': {'pos' : 50, 'neg': 50},
#                              'alice': {'pos' 50, 'neg': 50}},
#                      mode = 'val',
#                      pipes = [polarity_filter, doc_vectorizer]
#                     )
#
# # Create a torch data loaders
# trainloader = DataLoader(trainset, shuffle = True,
#                          batchsize = 16, workers = 2)
#
# valloader = DataLoader(valset, shuffle = False,
#                          batchsize = 16, workers = 2)
#
# ```
