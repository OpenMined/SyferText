# %% [markdown]
# # Sentiment Analysis with SyferText

# %% [markdown]
# ## Problem Statement (use it as twitter)

# %% [markdown]
# ## Demo Plan
#
# 1. How to use SyferText pipelines.

# %%
# Some imports
import syft as sy
from syft.generic.string import String
import torch
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import syfertext
import numpy as np
import tqdm
import csv
from sklearn.model_selection import train_test_split

hook = sy.TorchHook(torch)
# Out:
# WARNING:root:Torch was already hooked... skipping hooking process
# WARNING:root:Torch was already hooked... skipping hooking process
# WARNING:root:Torch was already hooked... skipping hooking process

# %% [markdown]
# Let's prepare the work environement:

# %%
# Create some PySyft workers
me = hook.local_worker
bob = sy.VirtualWorker(hook, id = 'bob')
alice = sy.VirtualWorker(hook, id = 'alice')
crypto_provider = sy.VirtualWorker(hook, id = 'crypto_provider')

# Create a summary writer for logging performance with tensorboard
writer = SummaryWriter()

# Create a Language object with SyferText
nlp = syfertext.load('en_core_web_lg', owner = me)

# %% [markdown]
# ## -3. Download the Dataset

# %% [markdown]
# ## -2. Load the Dataset

# %%
# Set the path to the dataset file
dataset_path = '../../../datasets/imdb/imdb.csv'

# store the dataset as a list of dictionaries
# each dictionary has two keys, 'review' and 'label'
# the 'review' element is a PySyft String
# the 'label' element is an integer with 1 for 'positive'
# and 0 for 'negative' review
dataset_local = []

with open(dataset_path, 'r') as dataset_file:
    
    # Create a csv reader object
    reader = csv.DictReader(dataset_file)
    
    for elem in reader:
        
        # Create one entry
        example = dict(review = String(elem['review']),
                       label = 1 if elem['sentiment'] == 'positive' else 0
                      )
        
        # add to the local dataset
        dataset_local.append(example)

# %%
dataset_local[0]['review'].owner, dataset_local[0]['label']
# Out:
# (<VirtualWorker id:me #objects:0>, 1)

# %% [markdown]
# ## -1. Send the Dataset to Remote Workers

# %% [markdown]
# Let's cut the dataset into two equal parts and send each part to a different worker simulating two remote datasets:

# %%
# Create two datasets, one for Bob, and the other for Alic
dataset_bob, dataset_alice = train_test_split(dataset_local, train_size = 0.5)

# Now create a validation set for Bob, and another for Alice
train_bob, val_bob = train_test_split(dataset_bob, train_size = 0.7)
train_alice, val_alice = train_test_split(dataset_alice, train_size = 0.7)

# %%
# Send the content of each split
def make_remote_dataset(dataset, worker):

    # Got through each example in the dataset
    for example in dataset:
        
        # Send each review text
        example['review'] = example['review'].send(worker)

        # Send each label as a one-hot-enceded vector
        one_hot_label = torch.zeros(2).scatter(0, torch.Tensor([example['label']]).long(), 1)
        example['label'] = one_hot_label.send(worker)

# %% [markdown]
# Make the datasets remote

# %%
make_remote_dataset(train_bob, bob)
make_remote_dataset(val_bob, bob)

make_remote_dataset(train_alice, alice)
make_remote_dataset(val_alice, alice)

# %%
print(type(train_bob[0]['review']))
print(train_bob[0]['review'].location)

print(type(train_bob[0]['label']))
print(train_bob[0]['label'].location)
# Out:
# <class 'syft.generic.pointers.string_pointer.StringPointer'>
# <VirtualWorker id:bob #objects:50000>
# <class 'torch.Tensor'>
# <VirtualWorker id:bob #objects:50000>

# %% [markdown]
# -----------

# %% [markdown]
# ## 0. Create a Dataset class

# %%
# This should go into the __getitem__ method of the dataloader

from torch.utils.data import Dataset

class DatasetIMDB(Dataset):
    
    def __init__(self, sets, share_workers, crypto_provider, nlp):
        
        self.sets = sets
        self.crypto_provider = crypto_provider
        self.workers = share_workers
    
        # Create a single dataset unifying all datasets
        self._create_dataset()
        
    def __getitem__(self, index):

        # get the example
        example = self.dataset[index]
        
        # Tokenize the string and get a doc pointer
        doc_ptr = nlp(example['review'])
        
        # Get the encrypted vector embedding for the document
        vector_enc = doc_ptr.get_encrypted_vector(bob, 
                                                  alice, 
                                                  crypto_provider = self.crypto_provider,
                                                  requires_grad = True
                                                 )
        try:
            # Encrypte the target label
            label_enc = example['label'].fix_precision().share(bob, 
                                                               alice, 
                                                               crypto_provider = self.crypto_provider,
                                                               requires_grad = True
                                                              ).get()
        except AttributeError:
            label_enc = example['label'].share(bob, 
                                                               alice, 
                                                               crypto_provider = self.crypto_provider,
                                                               requires_grad = True
                                                              ).get()
            
        return vector_enc, label_enc

    def __len__(self):
        
        # The size of the combined datasets
        return len(self.dataset)

    def _create_dataset(self):
        """Create a single dataset unifying examples from all remote datasets
        """
        # Initialize the dataset
        self.dataset = []
      
        # populate the dataset list
        for dataset in self.sets:
            for example in dataset:
                self.dataset.append(example)
                
    @staticmethod
    def collate_fn(batch):
        
        # Unzip the batch
        vectors, targets = list(zip(*batch))

        # concatenate the vectors
        vectors = torch.stack(vectors)
        
        #concatenate the labels
        targets = torch.stack(targets)
        
        return vectors, targets

# %% [markdown]
# ## 1. Create a DataLoader

# %%
learning_rate = 0.001
batch_size = 32
#learning_rate = 0.01
#batch_size = 128

# %% [markdown]
# Now, I should create the dataset handlers for training and validation as well as data loaders.
#
# This is a key step. You will notice that, although we have two different training sets, I create only one dataset handler for training and only one for validation.
#
# The training set handler will treat both training sets at bob's and alice's machine as one single big dataset.
#
# When the dataloader creates training batches, these batches will be composed of randomly picked examples for Bob and Alice's training sets. What makes mixing dataset in this way, without violating privacy is that fact that those training examples will be encrypted using SMPC with the help of PySyft.
#
# SyferText, makes it possible to process plain text at the remote worker without the need to transfer this data to the model owner's machine (us in this case). It also allows to encrypt the embedding vectors using PySyft before they quite their home machine.

# %%
from torch.utils.data import DataLoader

# Instantiate a training Dataset object
trainset = DatasetIMDB(sets = [train_bob,
                               train_alice],
                       share_workers = [bob, alice],
                       crypto_provider = crypto_provider,
                       nlp = nlp
                      )

# Instantiate a validation Dataset object
valset = DatasetIMDB(sets = [val_bob,
                             val_alice],
                     share_workers = [bob, alice],
                     crypto_provider = crypto_provider,
                     nlp = nlp
                    )

# Instantiate the DataLoader object for the training set
trainloader = DataLoader(trainset, shuffle = True,
                         batch_size = batch_size, num_workers = 0, 
                         collate_fn = trainset.collate_fn)


# Instantiate the DataLoader object for the validation set
valloader = DataLoader(valset, shuffle = True,
                       batch_size = batch_size, num_workers = 0, 
                       collate_fn = valset.collate_fn)

# %% [markdown]
# ## 2. Create an Encrypted Classifier

# %%
class Classifier(torch.nn.Module):
    
    def __init__(self, in_features, out_features):
        super(Classifier, self).__init__()
        
        self.fc = torch.nn.Linear(in_features, out_features)
                
    def forward(self, x):
        
        logits = self.fc(x)
        
        #preds = self.sig(logits)
        probs = F.relu(logits)
        
        return probs, logits

# %% [markdown]
# Iniitialize and encrypt the classifier:

# %%
classifier = Classifier(in_features = 300, out_features = 2)

# Apply SMPC encryption
classifier = classifier.fix_precision().share(bob, alice, 
                                              crypto_provider = crypto_provider,
                                              requires_grad = True
                                              )
print(classifier)
# Out:
# Classifier(
#   (fc): Linear(in_features=300, out_features=2, bias=True)
# )

# %% [markdown]
# ## 3. Start training

# %%
a = torch.Tensor([2., 3.])
a.fix_precision()
a
# Out:
# tensor([2., 3.])

# %%
# Out:
# (Wrapper)>[PointerTensor | me:23438792066 -> bob:18181931159]

# %%
# Out:
# (Wrapper)>FixedPrecisionTensor>tensor([2000, 3000])

# %%
# Create an optimizer
import torch.optim as optim


optim = optim.SGD(params = classifier.parameters(),
                   lr = learning_rate).fix_precision()
'''
optim = optim.Adam(params = classifier.parameters(),
                   lr = learning_rate)
'''
# Out:
# '\noptim = optim.Adam(params = classifier.parameters(),\n                   lr = learning_rate)\n'

# %%
def cycle(dataloader):
    while True:
        for vector, target in dataloader:
            yield vector, target

# %%
classifier.train()

for epoch in range(10):
    
    for iter, (vectors, targets) in enumerate(trainloader):

        classifier.train()

        # 1). Zero out previous gradients
        optim.zero_grad()

        # 2). predict sentiment probabilities
        probs, logits = classifier(vectors)

        # 3). Compute loss and accuracy
        loss = ((probs -  targets)**2).sum()#.refresh()# / len(train_data)


        # Get the predicted labels
        preds = probs.argmax(dim=1)
        targets = targets.argmax(dim=1)
        
        accuracy = preds.eq(targets).sum()
        accuracy = accuracy.get().float_precision()
        accuracy = 100 * (accuracy / batch_size)
        
        # 4). Backpropagate the loss
        loss.backward()

        # 5). Update weights
        optim.step()

        # decrypt the loss for logging
        loss = loss.get().float_precision()

        print(f"Ep {epoch} |  train loss: {loss}, train accuracy {accuracy:2} %")
        
        # Log to tensorboard
        writer.add_scalar('train/loss', loss, epoch * len(trainloader) + iter )
        writer.add_scalar('train/acc', accuracy, epoch * len(trainloader) + iter )

        
        # Perform validation on exactly one batch
        
        classifier.eval()

        for vectors, targets in valloader:
            
            
            probs, logits = classifier(vectors)

            loss = ((probs -  targets)**2).sum()

            preds = probs.argmax(dim=1)
            targets = targets.argmax(dim=1)

            accuracy = preds.eq(targets).sum()
            accuracy = accuracy.get().float_precision()
            accuracy = 100 * (accuracy / batch_size)

            loss = loss.get().float_precision()

            # Log to tensorboard
            writer.add_scalar('val/loss', loss, epoch * len(trainloader) + iter )
            writer.add_scalar('val/acc', accuracy, epoch * len(trainloader) + iter )
            
            break
            
writer.close()
# Out:
# Ep 0 |  train loss: 29.94300079345703, train accuracy 56.25 %
# Ep 0 |  train loss: 26.466999053955078, train accuracy 40.625 %
# Ep 0 |  train loss: 21.191999435424805, train accuracy 62.5 %
# Ep 0 |  train loss: 22.15399932861328, train accuracy 50.0 %
# Ep 0 |  train loss: 17.184999465942383, train accuracy 46.875 %
# Ep 0 |  train loss: 16.148000717163086, train accuracy 43.75 %
# Ep 0 |  train loss: 16.371000289916992, train accuracy 46.875 %
# Ep 0 |  train loss: 16.305999755859375, train accuracy 31.25 %
# Ep 0 |  train loss: 18.229999542236328, train accuracy 43.75 %
# Ep 0 |  train loss: 15.805999755859375, train accuracy 53.125 %
# Ep 0 |  train loss: 15.781000137329102, train accuracy 65.625 %
# Ep 0 |  train loss: 18.469999313354492, train accuracy 34.375 %
# Ep 0 |  train loss: 16.174999237060547, train accuracy 50.0 %
# Ep 0 |  train loss: 15.84000015258789, train accuracy 53.125 %
# Ep 0 |  train loss: 16.216999053955078, train accuracy 43.75 %
# Ep 0 |  train loss: 16.097999572753906, train accuracy 53.125 %
# Ep 0 |  train loss: 15.928000450134277, train accuracy 53.125 %
# Ep 0 |  train loss: 15.762999534606934, train accuracy 46.875 %
# Ep 0 |  train loss: 15.739999771118164, train accuracy 65.625 %
# Ep 0 |  train loss: 16.509000778198242, train accuracy 46.875 %
# Ep 0 |  train loss: 15.651000022888184, train accuracy 78.125 %
# Ep 0 |  train loss: 15.897000312805176, train accuracy 53.125 %
# Ep 0 |  train loss: 15.76200008392334, train accuracy 50.0 %
# Ep 0 |  train loss: 15.91100025177002, train accuracy 50.0 %
# Ep 0 |  train loss: 15.595999717712402, train accuracy 68.75 %
# Ep 0 |  train loss: 18.18199920654297, train accuracy 37.5 %
# Ep 0 |  train loss: 15.946000099182129, train accuracy 50.0 %
# Ep 0 |  train loss: 15.906999588012695, train accuracy 46.875 %
# Ep 0 |  train loss: 16.236000061035156, train accuracy 43.75 %
# Ep 0 |  train loss: 15.789999961853027, train accuracy 56.25 %
# Ep 0 |  train loss: 14.791999816894531, train accuracy 65.625 %
# Ep 0 |  train loss: 16.687000274658203, train accuracy 50.0 %
# Ep 0 |  train loss: 16.26799964904785, train accuracy 46.875 %
# Ep 0 |  train loss: 15.57699966430664, train accuracy 71.875 %
# Ep 0 |  train loss: 15.526000022888184, train accuracy 56.25 %
# Ep 0 |  train loss: 15.597999572753906, train accuracy 56.25 %
# Ep 0 |  train loss: 15.713000297546387, train accuracy 53.125 %
# Ep 0 |  train loss: 15.82800006866455, train accuracy 50.0 %
# Ep 0 |  train loss: 15.822999954223633, train accuracy 62.5 %
# Ep 0 |  train loss: 15.850000381469727, train accuracy 46.875 %
# Ep 0 |  train loss: 14.579000473022461, train accuracy 65.625 %
# Ep 0 |  train loss: 14.734999656677246, train accuracy 62.5 %
# Ep 0 |  train loss: 15.072999954223633, train accuracy 59.375 %
# Ep 0 |  train loss: 15.142000198364258, train accuracy 59.375 %
# Ep 0 |  train loss: 17.017000198364258, train accuracy 43.75 %
# Ep 0 |  train loss: 15.50100040435791, train accuracy 62.5 %
# Ep 0 |  train loss: 16.05699920654297, train accuracy 43.75 %
# Ep 0 |  train loss: 16.66699981689453, train accuracy 31.25 %
# Ep 0 |  train loss: 16.95199966430664, train accuracy 50.0 %
# Ep 0 |  train loss: 15.848999977111816, train accuracy 50.0 %
# Ep 0 |  train loss: 15.470999717712402, train accuracy 75.0 %
# Ep 0 |  train loss: 15.230999946594238, train accuracy 65.625 %
# Ep 0 |  train loss: 15.550000190734863, train accuracy 46.875 %
# Ep 0 |  train loss: 15.661999702453613, train accuracy 59.375 %
# Ep 0 |  train loss: 15.284000396728516, train accuracy 53.125 %
# Ep 0 |  train loss: 15.439000129699707, train accuracy 53.125 %
# Ep 0 |  train loss: 14.956000328063965, train accuracy 84.375 %
# Ep 0 |  train loss: 15.762999534606934, train accuracy 53.125 %
# Ep 0 |  train loss: 15.932999610900879, train accuracy 46.875 %
# Ep 0 |  train loss: 14.967000007629395, train accuracy 87.5 %
# Ep 0 |  train loss: 16.993000030517578, train accuracy 37.5 %
# Ep 0 |  train loss: 16.722000122070312, train accuracy 40.625 %
# Ep 0 |  train loss: 14.855999946594238, train accuracy 62.5 %
# Ep 0 |  train loss: 14.45199966430664, train accuracy 62.5 %
# Ep 0 |  train loss: 17.483999252319336, train accuracy 34.375 %
# Ep 0 |  train loss: 16.621000289916992, train accuracy 37.5 %
# Ep 0 |  train loss: 16.29599952697754, train accuracy 40.625 %
# Ep 0 |  train loss: 15.057000160217285, train accuracy 59.375 %
# Ep 0 |  train loss: 15.125, train accuracy 71.875 %
# Ep 0 |  train loss: 15.793000221252441, train accuracy 46.875 %
# Ep 0 |  train loss: 14.708999633789062, train accuracy 78.125 %
# Ep 0 |  train loss: 14.925999641418457, train accuracy 59.375 %
# Ep 0 |  train loss: 16.201000213623047, train accuracy 40.625 %
# Ep 0 |  train loss: 15.743000030517578, train accuracy 46.875 %
# Ep 0 |  train loss: 17.062000274658203, train accuracy 37.5 %
# Ep 0 |  train loss: 15.340999603271484, train accuracy 53.125 %
# Ep 0 |  train loss: 15.543000221252441, train accuracy 56.25 %
# Ep 0 |  train loss: 14.704999923706055, train accuracy 75.0 %
# Ep 0 |  train loss: 13.930000305175781, train accuracy 65.625 %
# Ep 0 |  train loss: 14.885000228881836, train accuracy 59.375 %
# Ep 0 |  train loss: 16.714000701904297, train accuracy 46.875 %
# Ep 0 |  train loss: 14.89799976348877, train accuracy 68.75 %
# Ep 0 |  train loss: 14.529000282287598, train accuracy 59.375 %
# Ep 0 |  train loss: 16.97800064086914, train accuracy 31.25 %
# Ep 0 |  train loss: 17.413000106811523, train accuracy 34.375 %
# Ep 0 |  train loss: 14.72700023651123, train accuracy 62.5 %
# Ep 0 |  train loss: 16.91900062561035, train accuracy 31.25 %
# Ep 0 |  train loss: 17.31999969482422, train accuracy 43.75 %
# Ep 0 |  train loss: 15.130000114440918, train accuracy 62.5 %
# Ep 0 |  train loss: 16.766000747680664, train accuracy 40.625 %
# Ep 0 |  train loss: 15.434000015258789, train accuracy 56.25 %
# Ep 0 |  train loss: 15.375, train accuracy 50.0 %
# Ep 0 |  train loss: 14.843999862670898, train accuracy 62.5 %
# Ep 0 |  train loss: 14.130000114440918, train accuracy 75.0 %
# Ep 0 |  train loss: 17.025999069213867, train accuracy 40.625 %
# Ep 0 |  train loss: 15.180000305175781, train accuracy 59.375 %
# Ep 0 |  train loss: 14.97700023651123, train accuracy 53.125 %
# Ep 0 |  train loss: 15.567000389099121, train accuracy 53.125 %
# Ep 0 |  train loss: 14.75100040435791, train accuracy 78.125 %
# Ep 0 |  train loss: 13.95300006866455, train accuracy 75.0 %
# Ep 0 |  train loss: 17.233999252319336, train accuracy 50.0 %
# Ep 0 |  train loss: 15.187999725341797, train accuracy 62.5 %
# Ep 0 |  train loss: 15.491000175476074, train accuracy 59.375 %
# Ep 0 |  train loss: 15.432999610900879, train accuracy 53.125 %
# Ep 0 |  train loss: 15.246000289916992, train accuracy 68.75 %
# Ep 0 |  train loss: 15.675000190734863, train accuracy 50.0 %
# Ep 0 |  train loss: 14.461999893188477, train accuracy 59.375 %
# Ep 0 |  train loss: 15.534000396728516, train accuracy 50.0 %
# Ep 0 |  train loss: 16.156999588012695, train accuracy 46.875 %
# Ep 0 |  train loss: 15.319000244140625, train accuracy 59.375 %
# Ep 0 |  train loss: 15.571999549865723, train accuracy 68.75 %
# Ep 0 |  train loss: 14.595000267028809, train accuracy 59.375 %
# Ep 0 |  train loss: 14.696000099182129, train accuracy 75.0 %
# Ep 0 |  train loss: 15.012999534606934, train accuracy 56.25 %
# Ep 0 |  train loss: 14.61299991607666, train accuracy 53.125 %
# Ep 0 |  train loss: 15.12399959564209, train accuracy 65.625 %
# Ep 0 |  train loss: 14.800000190734863, train accuracy 68.75 %
# Ep 0 |  train loss: 14.013999938964844, train accuracy 87.5 %
# Ep 0 |  train loss: 15.319000244140625, train accuracy 65.625 %
# Ep 0 |  train loss: 14.508999824523926, train accuracy 81.25 %
# Ep 0 |  train loss: 14.640999794006348, train accuracy 62.5 %
# Ep 0 |  train loss: 15.20300006866455, train accuracy 56.25 %
# Ep 0 |  train loss: 13.836000442504883, train accuracy 87.5 %
# Ep 0 |  train loss: 15.092000007629395, train accuracy 68.75 %
# Ep 0 |  train loss: 14.35200023651123, train accuracy 78.125 %
# Ep 0 |  train loss: 14.902999877929688, train accuracy 59.375 %
# Ep 0 |  train loss: 16.472999572753906, train accuracy 40.625 %
# Ep 0 |  train loss: 15.57800006866455, train accuracy 50.0 %
# Ep 0 |  train loss: 14.545999526977539, train accuracy 78.125 %
# Ep 0 |  train loss: 14.79800033569336, train accuracy 59.375 %
# Ep 0 |  train loss: 14.220000267028809, train accuracy 59.375 %
# Ep 0 |  train loss: 14.944000244140625, train accuracy 53.125 %
# Ep 0 |  train loss: 14.97599983215332, train accuracy 62.5 %
# Ep 0 |  train loss: 14.914999961853027, train accuracy 59.375 %
# Ep 0 |  train loss: 15.480999946594238, train accuracy 65.625 %
# Ep 0 |  train loss: 15.01200008392334, train accuracy 59.375 %
# Ep 0 |  train loss: 17.40399932861328, train accuracy 37.5 %
# Ep 0 |  train loss: 15.817000389099121, train accuracy 50.0 %
# Ep 0 |  train loss: 14.430000305175781, train accuracy 68.75 %
# Ep 0 |  train loss: 14.883999824523926, train accuracy 65.625 %
# Ep 0 |  train loss: 14.574000358581543, train accuracy 56.25 %
# Ep 0 |  train loss: 14.885000228881836, train accuracy 62.5 %
# Ep 0 |  train loss: 14.894000053405762, train accuracy 62.5 %
# Ep 0 |  train loss: 16.624000549316406, train accuracy 40.625 %
# Ep 0 |  train loss: 13.61400032043457, train accuracy 62.5 %
# Ep 0 |  train loss: 13.244999885559082, train accuracy 68.75 %
# Ep 0 |  train loss: 16.072999954223633, train accuracy 50.0 %
# Ep 0 |  train loss: 14.63599967956543, train accuracy 71.875 %
# Ep 0 |  train loss: 14.246999740600586, train accuracy 75.0 %
# Ep 0 |  train loss: 15.543999671936035, train accuracy 53.125 %
# Ep 0 |  train loss: 14.442999839782715, train accuracy 56.25 %
# Ep 0 |  train loss: 16.51099967956543, train accuracy 40.625 %
# Ep 0 |  train loss: 13.859000205993652, train accuracy 75.0 %
# Ep 0 |  train loss: 15.984999656677246, train accuracy 40.625 %
# Ep 0 |  train loss: 14.810999870300293, train accuracy 59.375 %
# Ep 0 |  train loss: 15.345000267028809, train accuracy 59.375 %
# Ep 0 |  train loss: 14.494000434875488, train accuracy 62.5 %
# Ep 0 |  train loss: 15.180000305175781, train accuracy 62.5 %
# Ep 0 |  train loss: 14.442000389099121, train accuracy 71.875 %
# Ep 0 |  train loss: 14.253000259399414, train accuracy 68.75 %
# Ep 0 |  train loss: 14.57699966430664, train accuracy 68.75 %
# Ep 0 |  train loss: 14.687999725341797, train accuracy 71.875 %
# Ep 0 |  train loss: 14.642999649047852, train accuracy 68.75 %
# Ep 0 |  train loss: 14.237000465393066, train accuracy 78.125 %
# Ep 0 |  train loss: 14.097000122070312, train accuracy 78.125 %
# Ep 0 |  train loss: 13.569999694824219, train accuracy 71.875 %
# Ep 0 |  train loss: 15.847000122070312, train accuracy 46.875 %
# Ep 0 |  train loss: 14.406000137329102, train accuracy 75.0 %
# Ep 0 |  train loss: 14.425999641418457, train accuracy 71.875 %
# Ep 0 |  train loss: 14.54800033569336, train accuracy 65.625 %
# Ep 0 |  train loss: 13.609000205993652, train accuracy 68.75 %
# Ep 0 |  train loss: 13.92199993133545, train accuracy 65.625 %
# Ep 0 |  train loss: 14.585000038146973, train accuracy 62.5 %
# Ep 0 |  train loss: 14.11299991607666, train accuracy 59.375 %
# Ep 0 |  train loss: 14.925000190734863, train accuracy 62.5 %
# Ep 0 |  train loss: 13.491999626159668, train accuracy 78.125 %
# Ep 0 |  train loss: 14.279999732971191, train accuracy 71.875 %
# Ep 0 |  train loss: 14.625, train accuracy 65.625 %
# Ep 0 |  train loss: 13.637999534606934, train accuracy 81.25 %
# Ep 0 |  train loss: 14.137999534606934, train accuracy 65.625 %
# Ep 0 |  train loss: 13.814000129699707, train accuracy 65.625 %
# Ep 0 |  train loss: 13.515999794006348, train accuracy 71.875 %
# Ep 0 |  train loss: 16.295000076293945, train accuracy 46.875 %
# Ep 0 |  train loss: 13.607000350952148, train accuracy 81.25 %
# Ep 0 |  train loss: 14.402999877929688, train accuracy 68.75 %
# Ep 0 |  train loss: 13.91100025177002, train accuracy 75.0 %
# Ep 0 |  train loss: 14.119999885559082, train accuracy 56.25 %
# Ep 0 |  train loss: 15.454000473022461, train accuracy 62.5 %
# Ep 0 |  train loss: 14.548999786376953, train accuracy 71.875 %
# Ep 0 |  train loss: 15.057999610900879, train accuracy 68.75 %
# Ep 0 |  train loss: 14.220999717712402, train accuracy 65.625 %
# Ep 0 |  train loss: 14.836000442504883, train accuracy 65.625 %
# Ep 0 |  train loss: 13.585000038146973, train accuracy 78.125 %
# Ep 0 |  train loss: 14.72599983215332, train accuracy 50.0 %
# Ep 0 |  train loss: 14.494000434875488, train accuracy 59.375 %
# Ep 0 |  train loss: 14.755999565124512, train accuracy 65.625 %
# Ep 0 |  train loss: 14.772000312805176, train accuracy 68.75 %
# Ep 0 |  train loss: 14.842000007629395, train accuracy 71.875 %
# Ep 0 |  train loss: 14.585000038146973, train accuracy 62.5 %
# Ep 0 |  train loss: 14.46500015258789, train accuracy 65.625 %
# Ep 0 |  train loss: 14.807999610900879, train accuracy 65.625 %
# Ep 0 |  train loss: 14.128999710083008, train accuracy 71.875 %
# Ep 0 |  train loss: 15.041000366210938, train accuracy 65.625 %
# Ep 0 |  train loss: 13.109999656677246, train accuracy 87.5 %
# Ep 0 |  train loss: 13.880999565124512, train accuracy 78.125 %
# Ep 0 |  train loss: 14.861000061035156, train accuracy 68.75 %
# Ep 0 |  train loss: 15.40999984741211, train accuracy 50.0 %
# Ep 0 |  train loss: 13.447999954223633, train accuracy 71.875 %
# Ep 0 |  train loss: 14.140999794006348, train accuracy 78.125 %
# Ep 0 |  train loss: 13.659000396728516, train accuracy 65.625 %
# Ep 0 |  train loss: 14.395000457763672, train accuracy 65.625 %
# Ep 0 |  train loss: 13.593000411987305, train accuracy 78.125 %
# Ep 0 |  train loss: 13.616999626159668, train accuracy 71.875 %
# Ep 0 |  train loss: 15.09000015258789, train accuracy 59.375 %
# Ep 0 |  train loss: 15.138999938964844, train accuracy 65.625 %
# Ep 0 |  train loss: 15.083000183105469, train accuracy 62.5 %
# Ep 0 |  train loss: 13.659000396728516, train accuracy 75.0 %
# Ep 0 |  train loss: 15.022000312805176, train accuracy 56.25 %
# Ep 0 |  train loss: 14.112000465393066, train accuracy 68.75 %
# Ep 0 |  train loss: 15.699999809265137, train accuracy 56.25 %
# Ep 0 |  train loss: 13.015999794006348, train accuracy 81.25 %
# Ep 0 |  train loss: 13.267999649047852, train accuracy 71.875 %
# Ep 0 |  train loss: 14.92199993133545, train accuracy 59.375 %
# Ep 0 |  train loss: 13.628000259399414, train accuracy 81.25 %
# Ep 0 |  train loss: 15.789999961853027, train accuracy 50.0 %
# Ep 0 |  train loss: 15.012999534606934, train accuracy 50.0 %
# Ep 0 |  train loss: 13.517000198364258, train accuracy 75.0 %
# Ep 0 |  train loss: 14.565999984741211, train accuracy 68.75 %
# Ep 0 |  train loss: 14.819999694824219, train accuracy 68.75 %
# Ep 0 |  train loss: 14.20300006866455, train accuracy 68.75 %
# Ep 0 |  train loss: 13.663999557495117, train accuracy 75.0 %
# Ep 0 |  train loss: 14.326000213623047, train accuracy 59.375 %
# Ep 0 |  train loss: 13.696999549865723, train accuracy 75.0 %
# Ep 0 |  train loss: 14.489999771118164, train accuracy 59.375 %
# Ep 0 |  train loss: 14.501999855041504, train accuracy 75.0 %
# Ep 0 |  train loss: 14.29800033569336, train accuracy 62.5 %
# Ep 0 |  train loss: 13.630000114440918, train accuracy 71.875 %
# Ep 0 |  train loss: 13.444000244140625, train accuracy 84.375 %
# Ep 0 |  train loss: 12.682999610900879, train accuracy 78.125 %
# Ep 0 |  train loss: 16.1299991607666, train accuracy 50.0 %
# Ep 0 |  train loss: 14.175999641418457, train accuracy 68.75 %
# Ep 0 |  train loss: 13.456999778747559, train accuracy 75.0 %
# Ep 0 |  train loss: 14.274999618530273, train accuracy 71.875 %
# Ep 0 |  train loss: 15.430000305175781, train accuracy 50.0 %
# Ep 0 |  train loss: 13.336000442504883, train accuracy 81.25 %
# Ep 0 |  train loss: 13.633000373840332, train accuracy 78.125 %
# Ep 0 |  train loss: 13.199000358581543, train accuracy 75.0 %
# Ep 0 |  train loss: 14.480999946594238, train accuracy 59.375 %
# Ep 0 |  train loss: 13.607000350952148, train accuracy 68.75 %
# Ep 0 |  train loss: 12.98900032043457, train accuracy 75.0 %
# Ep 0 |  train loss: 13.40999984741211, train accuracy 75.0 %
# Ep 0 |  train loss: 14.055000305175781, train accuracy 68.75 %
# Ep 0 |  train loss: 13.9399995803833, train accuracy 65.625 %
# Ep 0 |  train loss: 13.913999557495117, train accuracy 62.5 %
# Ep 0 |  train loss: 14.543000221252441, train accuracy 71.875 %
# Ep 0 |  train loss: 12.312999725341797, train accuracy 78.125 %
# Ep 0 |  train loss: 16.493999481201172, train accuracy 50.0 %
# Ep 0 |  train loss: 12.470000267028809, train accuracy 81.25 %
# Ep 0 |  train loss: 12.788999557495117, train accuracy 71.875 %
# Ep 0 |  train loss: 12.826000213623047, train accuracy 81.25 %
# Ep 0 |  train loss: 16.77199935913086, train accuracy 37.5 %
# Ep 0 |  train loss: 15.670999526977539, train accuracy 40.625 %
# Ep 0 |  train loss: 13.295999526977539, train accuracy 81.25 %
# Ep 0 |  train loss: 14.036999702453613, train accuracy 71.875 %
# Ep 0 |  train loss: 13.168000221252441, train accuracy 68.75 %
# Ep 0 |  train loss: 13.329000473022461, train accuracy 68.75 %
# Ep 0 |  train loss: 14.333000183105469, train accuracy 56.25 %
# Ep 0 |  train loss: 13.812999725341797, train accuracy 71.875 %
# Ep 0 |  train loss: 14.605999946594238, train accuracy 59.375 %
# Ep 0 |  train loss: 12.965999603271484, train accuracy 84.375 %
# Ep 0 |  train loss: 14.081999778747559, train accuracy 71.875 %
# Ep 0 |  train loss: 12.467000007629395, train accuracy 87.5 %
# Ep 0 |  train loss: 14.34000015258789, train accuracy 65.625 %
# Ep 0 |  train loss: 14.072999954223633, train accuracy 53.125 %
# Ep 0 |  train loss: 14.036999702453613, train accuracy 78.125 %
# Ep 0 |  train loss: 13.47599983215332, train accuracy 75.0 %
# Ep 0 |  train loss: 13.14900016784668, train accuracy 75.0 %
# Ep 0 |  train loss: 14.170999526977539, train accuracy 68.75 %
# Ep 0 |  train loss: 13.17300033569336, train accuracy 84.375 %
# Ep 0 |  train loss: 13.303999900817871, train accuracy 84.375 %
# Ep 0 |  train loss: 13.366999626159668, train accuracy 71.875 %
# Ep 0 |  train loss: 12.934000015258789, train accuracy 71.875 %
# Ep 0 |  train loss: 13.340999603271484, train accuracy 56.25 %
# Ep 0 |  train loss: 13.437999725341797, train accuracy 62.5 %
# Ep 0 |  train loss: 14.0, train accuracy 59.375 %
# Ep 0 |  train loss: 14.003999710083008, train accuracy 62.5 %
# Ep 0 |  train loss: 13.430999755859375, train accuracy 81.25 %
# Ep 0 |  train loss: 13.932999610900879, train accuracy 59.375 %
# Ep 0 |  train loss: 13.72599983215332, train accuracy 62.5 %
# Ep 0 |  train loss: 13.572999954223633, train accuracy 68.75 %
# Ep 0 |  train loss: 14.130999565124512, train accuracy 68.75 %
# Ep 0 |  train loss: 13.04800033569336, train accuracy 78.125 %
# Ep 0 |  train loss: 12.637999534606934, train accuracy 71.875 %
# Ep 0 |  train loss: 15.682999610900879, train accuracy 50.0 %
# Ep 0 |  train loss: 14.102999687194824, train accuracy 71.875 %
# Ep 0 |  train loss: 13.435999870300293, train accuracy 71.875 %
# Ep 0 |  train loss: 14.331000328063965, train accuracy 65.625 %
# Ep 0 |  train loss: 13.659000396728516, train accuracy 59.375 %
# Ep 0 |  train loss: 14.25100040435791, train accuracy 71.875 %
# Ep 0 |  train loss: 15.902000427246094, train accuracy 46.875 %
# Ep 0 |  train loss: 14.484999656677246, train accuracy 62.5 %
# Ep 0 |  train loss: 13.204999923706055, train accuracy 65.625 %
# Ep 0 |  train loss: 13.373000144958496, train accuracy 81.25 %
# Ep 0 |  train loss: 14.418999671936035, train accuracy 65.625 %
# Ep 0 |  train loss: 13.130000114440918, train accuracy 71.875 %
# Ep 0 |  train loss: 12.045000076293945, train accuracy 78.125 %
# Ep 0 |  train loss: 14.281000137329102, train accuracy 62.5 %
# Ep 0 |  train loss: 15.083000183105469, train accuracy 59.375 %
# Ep 0 |  train loss: 11.597000122070312, train accuracy 87.5 %
# Ep 0 |  train loss: 12.284000396728516, train accuracy 78.125 %
# Ep 0 |  train loss: 14.717000007629395, train accuracy 68.75 %
# Ep 0 |  train loss: 11.881999969482422, train accuracy 84.375 %
# Ep 0 |  train loss: 13.281000137329102, train accuracy 75.0 %
# Ep 0 |  train loss: 14.288999557495117, train accuracy 59.375 %
# Ep 0 |  train loss: 14.04800033569336, train accuracy 75.0 %
# Ep 0 |  train loss: 13.822999954223633, train accuracy 68.75 %
# Ep 0 |  train loss: 13.343999862670898, train accuracy 62.5 %
# Ep 0 |  train loss: 14.435999870300293, train accuracy 71.875 %
# Ep 0 |  train loss: 13.354999542236328, train accuracy 78.125 %
# Ep 0 |  train loss: 12.989999771118164, train accuracy 81.25 %
# Ep 0 |  train loss: 12.758000373840332, train accuracy 78.125 %
# Ep 0 |  train loss: 13.11400032043457, train accuracy 75.0 %
# Ep 0 |  train loss: 15.489999771118164, train accuracy 59.375 %
# Ep 0 |  train loss: 15.852999687194824, train accuracy 56.25 %
# Ep 0 |  train loss: 13.517999649047852, train accuracy 71.875 %
# Ep 0 |  train loss: 14.508000373840332, train accuracy 62.5 %
# Ep 0 |  train loss: 14.550000190734863, train accuracy 59.375 %
# Ep 0 |  train loss: 13.347000122070312, train accuracy 78.125 %
# Ep 0 |  train loss: 13.222999572753906, train accuracy 68.75 %
# Ep 0 |  train loss: 15.404999732971191, train accuracy 56.25 %
# Ep 0 |  train loss: 18.559999465942383, train accuracy 40.625 %
# Ep 0 |  train loss: 13.017999649047852, train accuracy 75.0 %
# Ep 0 |  train loss: 13.097000122070312, train accuracy 75.0 %
# Ep 0 |  train loss: 11.472000122070312, train accuracy 84.375 %
# Ep 0 |  train loss: 12.753999710083008, train accuracy 68.75 %
# Ep 0 |  train loss: 13.638999938964844, train accuracy 68.75 %
# Ep 0 |  train loss: 13.170999526977539, train accuracy 81.25 %
# Ep 0 |  train loss: 14.279000282287598, train accuracy 71.875 %
# Ep 0 |  train loss: 13.413000106811523, train accuracy 65.625 %
# Ep 0 |  train loss: 12.251999855041504, train accuracy 75.0 %
# Ep 0 |  train loss: 13.888999938964844, train accuracy 71.875 %
# Ep 0 |  train loss: 15.270999908447266, train accuracy 50.0 %
# Ep 0 |  train loss: 15.418000221252441, train accuracy 56.25 %
# Ep 0 |  train loss: 13.076000213623047, train accuracy 65.625 %
# Ep 0 |  train loss: 14.503999710083008, train accuracy 78.125 %
# Ep 0 |  train loss: 14.178999900817871, train accuracy 65.625 %
# Ep 0 |  train loss: 12.258999824523926, train accuracy 78.125 %
# Ep 0 |  train loss: 14.51099967956543, train accuracy 62.5 %
# Ep 0 |  train loss: 12.095999717712402, train accuracy 75.0 %
# Ep 0 |  train loss: 13.699999809265137, train accuracy 68.75 %
# Ep 0 |  train loss: 13.24899959564209, train accuracy 56.25 %
# Ep 0 |  train loss: 12.729999542236328, train accuracy 84.375 %
# Ep 0 |  train loss: 12.182000160217285, train accuracy 71.875 %
# Ep 0 |  train loss: 11.428999900817871, train accuracy 68.75 %
# Ep 0 |  train loss: 16.440000534057617, train accuracy 46.875 %
# Ep 0 |  train loss: 14.916999816894531, train accuracy 62.5 %
# Ep 0 |  train loss: 13.729000091552734, train accuracy 75.0 %
# Ep 0 |  train loss: 14.729000091552734, train accuracy 59.375 %
# Ep 0 |  train loss: 12.553000450134277, train accuracy 84.375 %
# Ep 0 |  train loss: 12.279999732971191, train accuracy 81.25 %
# Ep 0 |  train loss: 14.786999702453613, train accuracy 62.5 %
# Ep 0 |  train loss: 12.878000259399414, train accuracy 71.875 %
# Ep 0 |  train loss: 13.402000427246094, train accuracy 71.875 %
# Ep 0 |  train loss: 12.02400016784668, train accuracy 78.125 %
# Ep 0 |  train loss: 14.036999702453613, train accuracy 62.5 %
# Ep 0 |  train loss: 14.831999778747559, train accuracy 65.625 %
# Ep 0 |  train loss: 13.276000022888184, train accuracy 68.75 %
# Ep 0 |  train loss: 13.432000160217285, train accuracy 78.125 %
# Ep 0 |  train loss: 12.380000114440918, train accuracy 75.0 %
# Ep 0 |  train loss: 12.553999900817871, train accuracy 75.0 %
# Ep 0 |  train loss: 12.770999908447266, train accuracy 81.25 %
# Ep 0 |  train loss: 13.180999755859375, train accuracy 84.375 %
# Ep 0 |  train loss: 14.58899974822998, train accuracy 65.625 %
# Ep 0 |  train loss: 12.3149995803833, train accuracy 81.25 %
# Ep 0 |  train loss: 13.557999610900879, train accuracy 65.625 %
# Ep 0 |  train loss: 13.574000358581543, train accuracy 81.25 %
# Ep 0 |  train loss: 13.446000099182129, train accuracy 68.75 %
# Ep 0 |  train loss: 12.652000427246094, train accuracy 75.0 %
# Ep 0 |  train loss: 13.82699966430664, train accuracy 62.5 %
# Ep 0 |  train loss: 14.538999557495117, train accuracy 59.375 %
# Ep 0 |  train loss: 12.16100025177002, train accuracy 71.875 %
# Ep 0 |  train loss: 11.670999526977539, train accuracy 75.0 %
# Ep 0 |  train loss: 14.644000053405762, train accuracy 59.375 %
# Ep 0 |  train loss: 13.51200008392334, train accuracy 68.75 %
# Ep 0 |  train loss: 14.758000373840332, train accuracy 53.125 %
# Ep 0 |  train loss: 13.26200008392334, train accuracy 75.0 %
# Ep 0 |  train loss: 14.857999801635742, train accuracy 56.25 %
# Ep 0 |  train loss: 13.484999656677246, train accuracy 68.75 %
# Ep 0 |  train loss: 12.95300006866455, train accuracy 75.0 %
# Ep 0 |  train loss: 12.77400016784668, train accuracy 71.875 %
# Ep 0 |  train loss: 15.654999732971191, train accuracy 62.5 %
# Ep 0 |  train loss: 13.27400016784668, train accuracy 68.75 %
# Ep 0 |  train loss: 12.753000259399414, train accuracy 75.0 %
# Ep 0 |  train loss: 12.39900016784668, train accuracy 87.5 %
# Ep 0 |  train loss: 12.192999839782715, train accuracy 81.25 %
# Ep 0 |  train loss: 12.590999603271484, train accuracy 75.0 %
# Ep 0 |  train loss: 15.097999572753906, train accuracy 68.75 %
# Ep 0 |  train loss: 11.579999923706055, train accuracy 71.875 %
# Ep 0 |  train loss: 15.625, train accuracy 53.125 %
# Ep 0 |  train loss: 14.303000450134277, train accuracy 59.375 %
# Ep 0 |  train loss: 16.530000686645508, train accuracy 40.625 %
# Ep 0 |  train loss: 13.562000274658203, train accuracy 65.625 %
# Ep 0 |  train loss: 14.286999702453613, train accuracy 62.5 %
# Ep 0 |  train loss: 12.111000061035156, train accuracy 75.0 %
# Ep 0 |  train loss: 12.072999954223633, train accuracy 75.0 %
# Ep 0 |  train loss: 13.434000015258789, train accuracy 75.0 %
# Ep 0 |  train loss: 13.086999893188477, train accuracy 71.875 %
# Ep 0 |  train loss: 13.692000389099121, train accuracy 68.75 %
# Ep 0 |  train loss: 14.510000228881836, train accuracy 56.25 %
# Ep 0 |  train loss: 10.916000366210938, train accuracy 90.625 %
# Ep 0 |  train loss: 15.340999603271484, train accuracy 59.375 %
# Ep 0 |  train loss: 13.503000259399414, train accuracy 68.75 %
# Ep 0 |  train loss: 13.562999725341797, train accuracy 78.125 %
# Ep 0 |  train loss: 13.916000366210938, train accuracy 71.875 %
# Ep 0 |  train loss: 12.534000396728516, train accuracy 81.25 %
# Ep 0 |  train loss: 12.758999824523926, train accuracy 75.0 %
# Ep 0 |  train loss: 13.288000106811523, train accuracy 71.875 %
# Ep 0 |  train loss: 12.380000114440918, train accuracy 71.875 %
# Ep 0 |  train loss: 12.28499984741211, train accuracy 81.25 %
# Ep 0 |  train loss: 14.77299976348877, train accuracy 53.125 %
# Ep 0 |  train loss: 10.951000213623047, train accuracy 81.25 %
# Ep 0 |  train loss: 14.180999755859375, train accuracy 62.5 %
# Ep 0 |  train loss: 11.890000343322754, train accuracy 75.0 %
# Ep 0 |  train loss: 13.291000366210938, train accuracy 75.0 %
# Ep 0 |  train loss: 14.345000267028809, train accuracy 65.625 %
# Ep 0 |  train loss: 12.79800033569336, train accuracy 65.625 %
# Ep 0 |  train loss: 12.585000038146973, train accuracy 71.875 %
# Ep 0 |  train loss: 14.406999588012695, train accuracy 62.5 %
# Ep 0 |  train loss: 11.980999946594238, train accuracy 81.25 %
# Ep 0 |  train loss: 12.729999542236328, train accuracy 75.0 %
# Ep 0 |  train loss: 11.824000358581543, train accuracy 78.125 %
# Ep 0 |  train loss: 12.944000244140625, train accuracy 75.0 %
# Ep 0 |  train loss: 12.079999923706055, train accuracy 84.375 %
# Ep 0 |  train loss: 13.015000343322754, train accuracy 71.875 %
# Ep 0 |  train loss: 13.270000457763672, train accuracy 71.875 %
# Ep 0 |  train loss: 15.067000389099121, train accuracy 59.375 %
# Ep 0 |  train loss: 12.82800006866455, train accuracy 71.875 %
# Ep 0 |  train loss: 12.675000190734863, train accuracy 78.125 %
# Ep 0 |  train loss: 12.020000457763672, train accuracy 87.5 %
# Ep 0 |  train loss: 16.826000213623047, train accuracy 46.875 %
# Ep 0 |  train loss: 12.642000198364258, train accuracy 59.375 %
# Ep 0 |  train loss: 12.652000427246094, train accuracy 75.0 %
# Ep 0 |  train loss: 13.982999801635742, train accuracy 68.75 %
# Ep 0 |  train loss: 12.180999755859375, train accuracy 81.25 %
# Ep 0 |  train loss: 13.029999732971191, train accuracy 71.875 %
# Ep 0 |  train loss: 13.704000473022461, train accuracy 71.875 %
# Ep 0 |  train loss: 13.175999641418457, train accuracy 75.0 %
# Ep 0 |  train loss: 15.17199993133545, train accuracy 65.625 %
# Ep 0 |  train loss: 12.032999992370605, train accuracy 78.125 %
# Ep 0 |  train loss: 14.03499984741211, train accuracy 68.75 %
# Ep 0 |  train loss: 12.817999839782715, train accuracy 75.0 %
# Ep 0 |  train loss: 11.843000411987305, train accuracy 84.375 %
# Ep 0 |  train loss: 14.491000175476074, train accuracy 56.25 %
# Ep 0 |  train loss: 14.142999649047852, train accuracy 68.75 %
# Ep 0 |  train loss: 13.095000267028809, train accuracy 68.75 %
# Ep 0 |  train loss: 14.277999877929688, train accuracy 53.125 %
# Ep 0 |  train loss: 11.414999961853027, train accuracy 78.125 %
# Ep 0 |  train loss: 12.769000053405762, train accuracy 68.75 %
# Ep 0 |  train loss: 13.602999687194824, train accuracy 71.875 %
# Ep 0 |  train loss: 12.86400032043457, train accuracy 65.625 %
# Ep 0 |  train loss: 13.824000358581543, train accuracy 65.625 %
# Ep 0 |  train loss: 11.694999694824219, train accuracy 84.375 %
# Ep 0 |  train loss: 13.038999557495117, train accuracy 71.875 %
# Ep 0 |  train loss: 13.305999755859375, train accuracy 68.75 %
# Ep 0 |  train loss: 11.185999870300293, train accuracy 81.25 %
# Ep 0 |  train loss: 12.588000297546387, train accuracy 78.125 %
# Ep 0 |  train loss: 13.36299991607666, train accuracy 71.875 %
# Ep 0 |  train loss: 13.25100040435791, train accuracy 75.0 %
# Ep 0 |  train loss: 12.70199966430664, train accuracy 65.625 %
# Ep 0 |  train loss: 13.359999656677246, train accuracy 68.75 %
# Ep 0 |  train loss: 11.855999946594238, train accuracy 81.25 %
# Ep 0 |  train loss: 11.517000198364258, train accuracy 84.375 %
# Ep 0 |  train loss: 12.133999824523926, train accuracy 78.125 %
# Ep 0 |  train loss: 14.531999588012695, train accuracy 62.5 %
# Ep 0 |  train loss: 13.581999778747559, train accuracy 75.0 %
# Ep 0 |  train loss: 15.220000267028809, train accuracy 62.5 %
# Ep 0 |  train loss: 12.015999794006348, train accuracy 75.0 %
# Ep 0 |  train loss: 12.652000427246094, train accuracy 71.875 %
# Ep 0 |  train loss: 14.020999908447266, train accuracy 53.125 %
# Ep 0 |  train loss: 13.788999557495117, train accuracy 75.0 %
# Ep 0 |  train loss: 14.359000205993652, train accuracy 56.25 %
# Ep 0 |  train loss: 14.524999618530273, train accuracy 59.375 %
# Ep 0 |  train loss: 10.373000144958496, train accuracy 87.5 %
# Ep 0 |  train loss: 14.182000160217285, train accuracy 59.375 %
# Ep 0 |  train loss: 13.96399974822998, train accuracy 68.75 %
# Ep 0 |  train loss: 12.369999885559082, train accuracy 68.75 %
# Ep 0 |  train loss: 11.862000465393066, train accuracy 75.0 %
# Ep 0 |  train loss: 12.781000137329102, train accuracy 68.75 %
# Ep 0 |  train loss: 10.906000137329102, train accuracy 87.5 %
# Ep 0 |  train loss: 12.397000312805176, train accuracy 71.875 %
# Ep 0 |  train loss: 12.1850004196167, train accuracy 81.25 %
# Ep 0 |  train loss: 10.769000053405762, train accuracy 78.125 %
# Ep 0 |  train loss: 11.029999732971191, train accuracy 84.375 %
# Ep 0 |  train loss: 12.402000427246094, train accuracy 71.875 %
# Ep 0 |  train loss: 13.192999839782715, train accuracy 68.75 %
# Ep 0 |  train loss: 11.152999877929688, train accuracy 75.0 %
# Ep 0 |  train loss: 16.158000946044922, train accuracy 62.5 %
# Ep 0 |  train loss: 11.123000144958496, train accuracy 84.375 %
# Ep 0 |  train loss: 14.074999809265137, train accuracy 59.375 %
# Ep 0 |  train loss: 13.932000160217285, train accuracy 65.625 %
# Ep 0 |  train loss: 11.253000259399414, train accuracy 84.375 %
# Ep 0 |  train loss: 12.831999778747559, train accuracy 65.625 %
# Ep 0 |  train loss: 13.354000091552734, train accuracy 71.875 %
# Ep 0 |  train loss: 11.625, train accuracy 71.875 %
# Ep 0 |  train loss: 12.932000160217285, train accuracy 71.875 %
# Ep 0 |  train loss: 11.911999702453613, train accuracy 78.125 %
# Ep 0 |  train loss: 14.430000305175781, train accuracy 62.5 %
# Ep 0 |  train loss: 13.58899974822998, train accuracy 71.875 %
# Ep 0 |  train loss: 12.29800033569336, train accuracy 78.125 %
# Ep 0 |  train loss: 11.888999938964844, train accuracy 75.0 %
# Ep 0 |  train loss: 18.08300018310547, train accuracy 46.875 %
# Ep 0 |  train loss: 13.10200023651123, train accuracy 78.125 %
# Ep 0 |  train loss: 11.555000305175781, train accuracy 84.375 %
# Ep 0 |  train loss: 14.237000465393066, train accuracy 62.5 %
# Ep 0 |  train loss: 13.760000228881836, train accuracy 65.625 %
# Ep 0 |  train loss: 11.458000183105469, train accuracy 75.0 %
# Ep 0 |  train loss: 13.592000007629395, train accuracy 71.875 %
# Ep 0 |  train loss: 12.427000045776367, train accuracy 78.125 %
# Ep 0 |  train loss: 11.9350004196167, train accuracy 81.25 %
# Ep 0 |  train loss: 12.097000122070312, train accuracy 84.375 %
# Ep 0 |  train loss: 11.918000221252441, train accuracy 75.0 %
# Ep 0 |  train loss: 11.618000030517578, train accuracy 78.125 %
# Ep 0 |  train loss: 12.0649995803833, train accuracy 71.875 %
# Ep 0 |  train loss: 13.069000244140625, train accuracy 75.0 %
# Ep 0 |  train loss: 10.79699993133545, train accuracy 84.375 %
# Ep 0 |  train loss: 14.086999893188477, train accuracy 65.625 %
# Ep 0 |  train loss: 12.840999603271484, train accuracy 75.0 %
# Ep 0 |  train loss: 12.395000457763672, train accuracy 78.125 %
# Ep 0 |  train loss: 11.88700008392334, train accuracy 81.25 %
# Ep 0 |  train loss: 10.258999824523926, train accuracy 81.25 %
# Ep 0 |  train loss: 15.62399959564209, train accuracy 56.25 %
# Ep 0 |  train loss: 14.260000228881836, train accuracy 65.625 %
# Ep 0 |  train loss: 13.586999893188477, train accuracy 81.25 %
# Ep 0 |  train loss: 13.404999732971191, train accuracy 59.375 %
# Ep 0 |  train loss: 11.78499984741211, train accuracy 68.75 %
# Ep 0 |  train loss: 14.78600025177002, train accuracy 59.375 %
# Ep 0 |  train loss: 11.336000442504883, train accuracy 84.375 %
# Ep 0 |  train loss: 12.062999725341797, train accuracy 78.125 %
# Ep 0 |  train loss: 16.207000732421875, train accuracy 53.125 %
# Ep 0 |  train loss: 13.515000343322754, train accuracy 68.75 %
# Ep 0 |  train loss: 14.553000450134277, train accuracy 62.5 %
# Ep 0 |  train loss: 13.468999862670898, train accuracy 62.5 %
# Ep 0 |  train loss: 14.472000122070312, train accuracy 62.5 %
# Ep 0 |  train loss: 12.871000289916992, train accuracy 71.875 %
# Ep 0 |  train loss: 10.597000122070312, train accuracy 90.625 %
# Ep 0 |  train loss: 10.560999870300293, train accuracy 84.375 %
# Ep 0 |  train loss: 15.335000038146973, train accuracy 59.375 %
# Ep 0 |  train loss: 14.736000061035156, train accuracy 62.5 %
# Ep 0 |  train loss: 11.746000289916992, train accuracy 81.25 %
# Ep 0 |  train loss: 11.991999626159668, train accuracy 78.125 %
# Ep 0 |  train loss: 13.982000350952148, train accuracy 59.375 %
# Ep 0 |  train loss: 12.354999542236328, train accuracy 65.625 %
# Ep 0 |  train loss: 12.958999633789062, train accuracy 71.875 %
# Ep 0 |  train loss: 13.48900032043457, train accuracy 75.0 %
# Ep 0 |  train loss: 14.895000457763672, train accuracy 65.625 %
# Ep 0 |  train loss: 13.003000259399414, train accuracy 78.125 %
# Ep 0 |  train loss: 14.244999885559082, train accuracy 59.375 %
# Ep 0 |  train loss: 11.630000114440918, train accuracy 78.125 %
# Ep 0 |  train loss: 12.35200023651123, train accuracy 78.125 %
# Ep 0 |  train loss: 14.255000114440918, train accuracy 68.75 %
# Ep 0 |  train loss: 11.991000175476074, train accuracy 71.875 %
# Ep 0 |  train loss: 13.440999984741211, train accuracy 62.5 %
# Ep 0 |  train loss: 12.428999900817871, train accuracy 71.875 %
# Ep 0 |  train loss: 10.413000106811523, train accuracy 78.125 %
# Ep 0 |  train loss: 11.765999794006348, train accuracy 68.75 %
# Ep 0 |  train loss: 13.282999992370605, train accuracy 71.875 %
# Ep 0 |  train loss: 11.777999877929688, train accuracy 84.375 %
# Ep 0 |  train loss: 14.359999656677246, train accuracy 59.375 %
# Ep 0 |  train loss: 12.013999938964844, train accuracy 78.125 %
# Ep 0 |  train loss: 12.234999656677246, train accuracy 78.125 %
# Ep 0 |  train loss: 13.598999977111816, train accuracy 68.75 %
# Ep 0 |  train loss: 12.555000305175781, train accuracy 87.5 %
# Ep 0 |  train loss: 12.906999588012695, train accuracy 75.0 %
# Ep 0 |  train loss: 13.326000213623047, train accuracy 71.875 %
# Ep 0 |  train loss: 13.015999794006348, train accuracy 68.75 %
# Ep 0 |  train loss: 12.755999565124512, train accuracy 78.125 %
# Ep 0 |  train loss: 10.621000289916992, train accuracy 81.25 %
# Ep 0 |  train loss: 14.5600004196167, train accuracy 71.875 %
# Ep 0 |  train loss: 11.47700023651123, train accuracy 78.125 %
# Ep 0 |  train loss: 12.07800006866455, train accuracy 62.5 %
# Ep 0 |  train loss: 13.09000015258789, train accuracy 75.0 %
# Ep 0 |  train loss: 11.8100004196167, train accuracy 84.375 %
# Ep 0 |  train loss: 12.427000045776367, train accuracy 71.875 %
# Ep 0 |  train loss: 9.815999984741211, train accuracy 87.5 %
# Ep 0 |  train loss: 11.456000328063965, train accuracy 87.5 %
# Ep 0 |  train loss: 12.378999710083008, train accuracy 75.0 %
# Ep 0 |  train loss: 12.937000274658203, train accuracy 75.0 %
# Ep 0 |  train loss: 12.40999984741211, train accuracy 65.625 %
# Ep 0 |  train loss: 10.994999885559082, train accuracy 90.625 %
# Ep 0 |  train loss: 13.906999588012695, train accuracy 62.5 %
# Ep 0 |  train loss: 12.118000030517578, train accuracy 71.875 %
# Ep 0 |  train loss: 13.284000396728516, train accuracy 65.625 %
# Ep 0 |  train loss: 14.829000473022461, train accuracy 65.625 %
# Ep 0 |  train loss: 11.734999656677246, train accuracy 78.125 %
# Ep 0 |  train loss: 12.468000411987305, train accuracy 65.625 %
# Ep 0 |  train loss: 11.758999824523926, train accuracy 84.375 %
# Ep 0 |  train loss: 12.425999641418457, train accuracy 75.0 %
# Ep 0 |  train loss: 14.699999809265137, train accuracy 56.25 %
# Ep 0 |  train loss: 13.473999977111816, train accuracy 62.5 %
# Ep 0 |  train loss: 12.147000312805176, train accuracy 75.0 %
# Ep 0 |  train loss: 12.015000343322754, train accuracy 75.0 %
# Ep 0 |  train loss: 10.029999732971191, train accuracy 90.625 %
# Ep 0 |  train loss: 14.095000267028809, train accuracy 65.625 %
# Ep 0 |  train loss: 10.282999992370605, train accuracy 78.125 %
# Ep 0 |  train loss: 12.468999862670898, train accuracy 71.875 %
# Ep 0 |  train loss: 12.222999572753906, train accuracy 78.125 %
# Ep 0 |  train loss: 12.776000022888184, train accuracy 65.625 %
# Ep 0 |  train loss: 12.303000450134277, train accuracy 71.875 %
# Ep 0 |  train loss: 12.444000244140625, train accuracy 65.625 %
# Ep 0 |  train loss: 12.663999557495117, train accuracy 71.875 %
# Ep 0 |  train loss: 12.092000007629395, train accuracy 84.375 %
# Ep 0 |  train loss: 11.366000175476074, train accuracy 78.125 %
# Ep 0 |  train loss: 13.27299976348877, train accuracy 62.5 %
# Ep 0 |  train loss: 12.435999870300293, train accuracy 75.0 %
# Ep 0 |  train loss: 9.809000015258789, train accuracy 90.625 %
# Ep 0 |  train loss: 12.59000015258789, train accuracy 75.0 %
# Ep 0 |  train loss: 13.305000305175781, train accuracy 65.625 %
# Ep 0 |  train loss: 12.039999961853027, train accuracy 81.25 %
# Ep 0 |  train loss: 11.581999778747559, train accuracy 84.375 %
# Ep 0 |  train loss: 14.11299991607666, train accuracy 71.875 %
# Ep 0 |  train loss: 13.914999961853027, train accuracy 71.875 %
# Ep 0 |  train loss: 12.223999977111816, train accuracy 84.375 %
# Ep 0 |  train loss: 11.187000274658203, train accuracy 75.0 %
# Ep 0 |  train loss: 11.892999649047852, train accuracy 75.0 %
# Ep 0 |  train loss: 11.196000099182129, train accuracy 84.375 %
# Ep 0 |  train loss: 15.729000091552734, train accuracy 59.375 %
# Ep 0 |  train loss: 12.03499984741211, train accuracy 75.0 %
# Ep 0 |  train loss: 12.637999534606934, train accuracy 71.875 %
# Ep 0 |  train loss: 12.151000022888184, train accuracy 87.5 %
# Ep 0 |  train loss: 12.479999542236328, train accuracy 71.875 %
# Ep 0 |  train loss: 10.991000175476074, train accuracy 84.375 %
# Ep 0 |  train loss: 13.37399959564209, train accuracy 68.75 %
# Ep 0 |  train loss: 12.04800033569336, train accuracy 90.625 %
# Ep 0 |  train loss: 10.34000015258789, train accuracy 87.5 %
# Ep 0 |  train loss: 15.96399974822998, train accuracy 43.75 %
# Ep 0 |  train loss: 13.11299991607666, train accuracy 78.125 %
# Ep 0 |  train loss: 12.935999870300293, train accuracy 78.125 %
# Ep 0 |  train loss: 9.496999740600586, train accuracy 87.5 %
# Ep 0 |  train loss: 10.59000015258789, train accuracy 81.25 %
# Ep 0 |  train loss: 15.314000129699707, train accuracy 59.375 %
# Ep 0 |  train loss: 14.732999801635742, train accuracy 56.25 %
# Ep 0 |  train loss: 11.8100004196167, train accuracy 71.875 %
# Ep 0 |  train loss: 13.26099967956543, train accuracy 65.625 %
# Ep 0 |  train loss: 10.765999794006348, train accuracy 78.125 %
# Ep 0 |  train loss: 11.949000358581543, train accuracy 71.875 %
# Ep 0 |  train loss: 13.064000129699707, train accuracy 78.125 %
# Ep 0 |  train loss: 11.940999984741211, train accuracy 71.875 %
# Ep 0 |  train loss: 12.840999603271484, train accuracy 81.25 %
# Ep 0 |  train loss: 11.972000122070312, train accuracy 87.5 %
# Ep 0 |  train loss: 11.935999870300293, train accuracy 75.0 %
# Ep 0 |  train loss: 12.779000282287598, train accuracy 75.0 %
# Ep 0 |  train loss: 12.706999778747559, train accuracy 78.125 %
# Ep 0 |  train loss: 13.032999992370605, train accuracy 62.5 %
# Ep 0 |  train loss: 13.059000015258789, train accuracy 68.75 %
# Ep 0 |  train loss: 13.475000381469727, train accuracy 68.75 %
# Ep 0 |  train loss: 11.463000297546387, train accuracy 81.25 %
# Ep 0 |  train loss: 13.319999694824219, train accuracy 62.5 %
# Ep 0 |  train loss: 11.02299976348877, train accuracy 75.0 %
# Ep 0 |  train loss: 11.369000434875488, train accuracy 90.625 %
# Ep 0 |  train loss: 11.991999626159668, train accuracy 78.125 %
# Ep 0 |  train loss: 12.175000190734863, train accuracy 78.125 %
# Ep 0 |  train loss: 13.151000022888184, train accuracy 75.0 %
# Ep 0 |  train loss: 11.196999549865723, train accuracy 87.5 %
# Ep 0 |  train loss: 11.704000473022461, train accuracy 75.0 %
# Ep 0 |  train loss: 13.795999526977539, train accuracy 65.625 %
# Ep 0 |  train loss: 13.63700008392334, train accuracy 68.75 %
# Ep 0 |  train loss: 10.58899974822998, train accuracy 78.125 %
# Ep 0 |  train loss: 12.687999725341797, train accuracy 75.0 %
# Ep 0 |  train loss: 14.354000091552734, train accuracy 65.625 %
# Ep 0 |  train loss: 11.032999992370605, train accuracy 87.5 %
# Ep 0 |  train loss: 10.234999656677246, train accuracy 90.625 %
# Ep 0 |  train loss: 14.920999526977539, train accuracy 56.25 %
# Ep 0 |  train loss: 14.178000450134277, train accuracy 56.25 %
# Ep 0 |  train loss: 10.741000175476074, train accuracy 84.375 %
# Ep 0 |  train loss: 12.501999855041504, train accuracy 65.625 %
# Ep 0 |  train loss: 12.060999870300293, train accuracy 65.625 %
# Ep 0 |  train loss: 11.982000350952148, train accuracy 75.0 %
# Ep 0 |  train loss: 11.468999862670898, train accuracy 78.125 %
# Ep 0 |  train loss: 11.838000297546387, train accuracy 78.125 %
# Ep 0 |  train loss: 11.418000221252441, train accuracy 78.125 %
# Ep 0 |  train loss: 10.980999946594238, train accuracy 81.25 %
# Ep 0 |  train loss: 10.565999984741211, train accuracy 75.0 %
# Ep 0 |  train loss: 15.133000373840332, train accuracy 59.375 %
# Ep 0 |  train loss: 12.843999862670898, train accuracy 68.75 %
# Ep 0 |  train loss: 12.470999717712402, train accuracy 75.0 %
# Ep 0 |  train loss: 13.444999694824219, train accuracy 59.375 %
# Ep 0 |  train loss: 13.322999954223633, train accuracy 71.875 %
# Ep 0 |  train loss: 12.230999946594238, train accuracy 71.875 %
# Ep 0 |  train loss: 12.49899959564209, train accuracy 71.875 %
# Ep 0 |  train loss: 11.645999908447266, train accuracy 75.0 %
# Ep 0 |  train loss: 14.196999549865723, train accuracy 65.625 %
# Ep 0 |  train loss: 12.732000350952148, train accuracy 75.0 %
# Ep 0 |  train loss: 11.12600040435791, train accuracy 87.5 %
# Ep 0 |  train loss: 12.255999565124512, train accuracy 71.875 %
# Ep 0 |  train loss: 12.602999687194824, train accuracy 78.125 %
# Ep 0 |  train loss: 12.152000427246094, train accuracy 78.125 %
# Ep 0 |  train loss: 12.765000343322754, train accuracy 59.375 %
# Ep 0 |  train loss: 10.036999702453613, train accuracy 96.875 %
# Ep 0 |  train loss: 11.961999893188477, train accuracy 81.25 %
# Ep 0 |  train loss: 14.590999603271484, train accuracy 65.625 %
# Ep 0 |  train loss: 9.954999923706055, train accuracy 93.75 %
# Ep 0 |  train loss: 11.083000183105469, train accuracy 87.5 %
# Ep 0 |  train loss: 12.682999610900879, train accuracy 71.875 %
# Ep 0 |  train loss: 11.9350004196167, train accuracy 78.125 %
# Ep 0 |  train loss: 11.446000099182129, train accuracy 68.75 %
# Ep 0 |  train loss: 12.517000198364258, train accuracy 75.0 %
# Ep 0 |  train loss: 11.51200008392334, train accuracy 84.375 %
# Ep 0 |  train loss: 12.107999801635742, train accuracy 71.875 %
# Ep 0 |  train loss: 10.595000267028809, train accuracy 78.125 %
# Ep 0 |  train loss: 9.383000373840332, train accuracy 87.5 %
# Ep 0 |  train loss: 13.45199966430664, train accuracy 62.5 %
# Ep 0 |  train loss: 12.17300033569336, train accuracy 75.0 %
# Ep 0 |  train loss: 12.512999534606934, train accuracy 75.0 %
# Ep 0 |  train loss: 12.095000267028809, train accuracy 65.625 %
# Ep 0 |  train loss: 13.175999641418457, train accuracy 68.75 %
# Ep 0 |  train loss: 12.531000137329102, train accuracy 71.875 %
# Ep 0 |  train loss: 9.862000465393066, train accuracy 87.5 %
# Ep 0 |  train loss: 15.850000381469727, train accuracy 65.625 %
# Ep 0 |  train loss: 15.595000267028809, train accuracy 53.125 %
# Ep 0 |  train loss: 14.826000213623047, train accuracy 62.5 %
# Ep 0 |  train loss: 11.982999801635742, train accuracy 75.0 %
# Ep 0 |  train loss: 11.42199993133545, train accuracy 75.0 %
# Ep 0 |  train loss: 14.769000053405762, train accuracy 62.5 %
# Ep 0 |  train loss: 12.871000289916992, train accuracy 68.75 %
# Ep 0 |  train loss: 12.34000015258789, train accuracy 81.25 %
# Ep 0 |  train loss: 10.458999633789062, train accuracy 81.25 %
# Ep 0 |  train loss: 11.98900032043457, train accuracy 68.75 %
# Ep 0 |  train loss: 11.559000015258789, train accuracy 75.0 %
# Ep 0 |  train loss: 13.217000007629395, train accuracy 75.0 %
# Ep 0 |  train loss: 11.583999633789062, train accuracy 75.0 %
# Ep 0 |  train loss: 10.156999588012695, train accuracy 84.375 %
# Ep 0 |  train loss: 8.317999839782715, train accuracy 93.75 %
# Ep 0 |  train loss: 12.784000396728516, train accuracy 68.75 %
# Ep 0 |  train loss: 12.713000297546387, train accuracy 75.0 %
# Ep 0 |  train loss: 14.836999893188477, train accuracy 68.75 %
# Ep 0 |  train loss: 13.767000198364258, train accuracy 75.0 %
# Ep 0 |  train loss: 10.855999946594238, train accuracy 84.375 %
# Ep 0 |  train loss: 14.501999855041504, train accuracy 59.375 %
# Ep 0 |  train loss: 12.553999900817871, train accuracy 71.875 %
# Ep 0 |  train loss: 10.743000030517578, train accuracy 84.375 %
# Ep 0 |  train loss: 13.142000198364258, train accuracy 68.75 %
# Ep 0 |  train loss: 12.128999710083008, train accuracy 71.875 %
# Ep 0 |  train loss: 14.36400032043457, train accuracy 68.75 %
# Ep 0 |  train loss: 13.258000373840332, train accuracy 75.0 %
# Ep 0 |  train loss: 11.800000190734863, train accuracy 78.125 %
# Ep 0 |  train loss: 13.109999656677246, train accuracy 65.625 %
# Ep 0 |  train loss: 14.270000457763672, train accuracy 62.5 %
# Ep 0 |  train loss: 11.982999801635742, train accuracy 75.0 %
# Ep 0 |  train loss: 10.979999542236328, train accuracy 84.375 %
# Ep 0 |  train loss: 11.78499984741211, train accuracy 71.875 %
# Ep 0 |  train loss: 11.392000198364258, train accuracy 81.25 %
# Ep 0 |  train loss: 11.461000442504883, train accuracy 78.125 %
# Ep 0 |  train loss: 12.053000450134277, train accuracy 81.25 %
# Ep 0 |  train loss: 9.71399974822998, train accuracy 84.375 %
# Ep 0 |  train loss: 13.361000061035156, train accuracy 62.5 %
# Ep 0 |  train loss: 11.361000061035156, train accuracy 78.125 %
# Ep 0 |  train loss: 13.444999694824219, train accuracy 68.75 %
# Ep 0 |  train loss: 13.423999786376953, train accuracy 65.625 %
# Ep 0 |  train loss: 10.5649995803833, train accuracy 75.0 %
# Ep 0 |  train loss: 13.074000358581543, train accuracy 71.875 %
# Ep 0 |  train loss: 9.163999557495117, train accuracy 90.625 %
# Ep 0 |  train loss: 10.39900016784668, train accuracy 84.375 %
# ...
# Ep 1 |  train loss: 9.755000114440918, train accuracy 87.5 %
# Ep 1 |  train loss: 10.63599967956543, train accuracy 75.0 %
# Ep 1 |  train loss: 10.402999877929688, train accuracy 75.0 %
# Ep 1 |  train loss: 11.027000427246094, train accuracy 78.125 %
# Ep 1 |  train loss: 12.536999702453613, train accuracy 59.375 %
# Ep 1 |  train loss: 8.657999992370605, train accuracy 81.25 %
# Ep 1 |  train loss: 8.477999687194824, train accuracy 81.25 %
# Ep 1 |  train loss: 8.772000312805176, train accuracy 84.375 %
# Ep 1 |  train loss: 10.194000244140625, train accuracy 75.0 %
# Ep 1 |  train loss: 10.326000213623047, train accuracy 78.125 %
# Ep 1 |  train loss: 9.666000366210938, train accuracy 84.375 %
# Ep 1 |  train loss: 7.452000141143799, train accuracy 93.75 %
# Ep 1 |  train loss: 9.140999794006348, train accuracy 87.5 %
# Ep 1 |  train loss: 10.0, train accuracy 78.125 %
# Ep 1 |  train loss: 6.998000144958496, train accuracy 87.5 %
# Ep 1 |  train loss: 11.720000267028809, train accuracy 75.0 %
# Ep 1 |  train loss: 11.067999839782715, train accuracy 81.25 %
# Ep 1 |  train loss: 11.057999610900879, train accuracy 81.25 %
# Ep 1 |  train loss: 14.097000122070312, train accuracy 75.0 %
# Ep 1 |  train loss: 10.338000297546387, train accuracy 81.25 %
# Ep 1 |  train loss: 11.416000366210938, train accuracy 78.125 %
# Ep 1 |  train loss: 9.027000427246094, train accuracy 81.25 %
# Ep 1 |  train loss: 6.178999900817871, train accuracy 87.5 %
# Ep 1 |  train loss: 7.985000133514404, train accuracy 81.25 %
# Ep 1 |  train loss: 8.25100040435791, train accuracy 87.5 %
# Ep 1 |  train loss: 9.432000160217285, train accuracy 84.375 %
# Ep 1 |  train loss: 12.187999725341797, train accuracy 65.625 %
# Ep 1 |  train loss: 9.993000030517578, train accuracy 81.25 %
# Ep 1 |  train loss: 8.053000450134277, train accuracy 87.5 %
# Ep 1 |  train loss: 8.737000465393066, train accuracy 81.25 %
# Ep 1 |  train loss: 9.680999755859375, train accuracy 84.375 %
# Ep 1 |  train loss: 9.614999771118164, train accuracy 81.25 %
# Ep 1 |  train loss: 5.656000137329102, train accuracy 62.5 %
# Ep 2 |  train loss: 9.418999671936035, train accuracy 84.375 %
# Ep 2 |  train loss: 11.147000312805176, train accuracy 71.875 %
# Ep 2 |  train loss: 10.288000106811523, train accuracy 71.875 %
# Ep 2 |  train loss: 11.71399974822998, train accuracy 75.0 %
# Ep 2 |  train loss: 7.60099983215332, train accuracy 87.5 %
# Ep 2 |  train loss: 8.295000076293945, train accuracy 93.75 %
# Ep 2 |  train loss: 9.348999977111816, train accuracy 81.25 %
# Ep 2 |  train loss: 8.631999969482422, train accuracy 90.625 %
# Ep 2 |  train loss: 10.788999557495117, train accuracy 78.125 %
# Ep 2 |  train loss: 9.949000358581543, train accuracy 75.0 %
# Ep 2 |  train loss: 9.91100025177002, train accuracy 78.125 %
# Ep 2 |  train loss: 10.36299991607666, train accuracy 75.0 %
# Ep 2 |  train loss: 11.892999649047852, train accuracy 71.875 %
# Ep 2 |  train loss: 8.37399959564209, train accuracy 81.25 %
# Ep 2 |  train loss: 9.711000442504883, train accuracy 81.25 %
# Ep 2 |  train loss: 11.515999794006348, train accuracy 81.25 %
# Ep 2 |  train loss: 7.992000102996826, train accuracy 87.5 %
# Ep 2 |  train loss: 9.48799991607666, train accuracy 84.375 %
# Ep 2 |  train loss: 13.166000366210938, train accuracy 68.75 %
# Ep 2 |  train loss: 9.482000350952148, train accuracy 87.5 %
# Ep 2 |  train loss: 11.234000205993652, train accuracy 81.25 %
# Ep 2 |  train loss: 10.54699993133545, train accuracy 78.125 %
# Ep 2 |  train loss: 9.026000022888184, train accuracy 78.125 %
# Ep 2 |  train loss: 9.050000190734863, train accuracy 84.375 %
# Ep 2 |  train loss: 10.361000061035156, train accuracy 75.0 %
# Ep 2 |  train loss: 8.605999946594238, train accuracy 90.625 %
# Ep 2 |  train loss: 10.173999786376953, train accuracy 78.125 %
# Ep 2 |  train loss: 10.5649995803833, train accuracy 68.75 %
# Ep 2 |  train loss: 12.145999908447266, train accuracy 75.0 %
# Ep 2 |  train loss: 7.723999977111816, train accuracy 84.375 %
# Ep 2 |  train loss: 10.048999786376953, train accuracy 78.125 %
# Ep 2 |  train loss: 8.935999870300293, train accuracy 71.875 %
# Ep 2 |  train loss: 9.182999610900879, train accuracy 87.5 %
# Ep 2 |  train loss: 7.8429999351501465, train accuracy 90.625 %
# Ep 2 |  train loss: 8.916000366210938, train accuracy 87.5 %
# Ep 2 |  train loss: 9.199999809265137, train accuracy 81.25 %
# Ep 2 |  train loss: 11.779000282287598, train accuracy 75.0 %
# Ep 2 |  train loss: 11.383000373840332, train accuracy 68.75 %
# Ep 2 |  train loss: 9.484000205993652, train accuracy 84.375 %
# Ep 2 |  train loss: 9.39900016784668, train accuracy 87.5 %
# Ep 2 |  train loss: 10.581000328063965, train accuracy 81.25 %
# Ep 2 |  train loss: 8.744000434875488, train accuracy 84.375 %
# Ep 2 |  train loss: 11.72700023651123, train accuracy 75.0 %
# Ep 2 |  train loss: 8.809000015258789, train accuracy 84.375 %
# Ep 2 |  train loss: 8.239999771118164, train accuracy 84.375 %
# Ep 2 |  train loss: 12.812000274658203, train accuracy 68.75 %
# Ep 2 |  train loss: 9.508999824523926, train accuracy 81.25 %
# Ep 2 |  train loss: 9.809000015258789, train accuracy 78.125 %
# Ep 2 |  train loss: 11.472999572753906, train accuracy 75.0 %
# Ep 2 |  train loss: 10.755000114440918, train accuracy 78.125 %
# Ep 2 |  train loss: 8.168000221252441, train accuracy 75.0 %
# Ep 2 |  train loss: 10.824000358581543, train accuracy 71.875 %
# Ep 2 |  train loss: 10.607000350952148, train accuracy 84.375 %
# Ep 2 |  train loss: 11.100000381469727, train accuracy 62.5 %
# Ep 2 |  train loss: 8.756999969482422, train accuracy 84.375 %
# Ep 2 |  train loss: 8.175000190734863, train accuracy 78.125 %
# Ep 2 |  train loss: 8.46500015258789, train accuracy 87.5 %
# Ep 2 |  train loss: 10.5600004196167, train accuracy 81.25 %
# Ep 2 |  train loss: 9.692000389099121, train accuracy 81.25 %
# Ep 2 |  train loss: 8.409000396728516, train accuracy 84.375 %
# Ep 2 |  train loss: 7.994999885559082, train accuracy 84.375 %
# Ep 2 |  train loss: 11.314000129699707, train accuracy 71.875 %
# Ep 2 |  train loss: 9.036999702453613, train accuracy 75.0 %
# Ep 2 |  train loss: 9.63700008392334, train accuracy 78.125 %
# Ep 2 |  train loss: 11.767999649047852, train accuracy 75.0 %
# Ep 2 |  train loss: 11.890999794006348, train accuracy 65.625 %
# Ep 2 |  train loss: 9.527999877929688, train accuracy 84.375 %
# Ep 2 |  train loss: 9.949000358581543, train accuracy 87.5 %
# Ep 2 |  train loss: 10.548999786376953, train accuracy 71.875 %
# Ep 2 |  train loss: 8.684000015258789, train accuracy 84.375 %
# Ep 2 |  train loss: 9.782999992370605, train accuracy 75.0 %
# Ep 2 |  train loss: 9.569999694824219, train accuracy 81.25 %
# Ep 2 |  train loss: 12.267000198364258, train accuracy 71.875 %
# Ep 2 |  train loss: 11.755999565124512, train accuracy 75.0 %
# Ep 2 |  train loss: 9.361000061035156, train accuracy 84.375 %
# Ep 2 |  train loss: 7.624000072479248, train accuracy 90.625 %
# Ep 2 |  train loss: 7.002999782562256, train accuracy 87.5 %
# Ep 2 |  train loss: 10.272000312805176, train accuracy 84.375 %
# Ep 2 |  train loss: 10.119000434875488, train accuracy 78.125 %
# Ep 2 |  train loss: 9.069000244140625, train accuracy 87.5 %
# Ep 2 |  train loss: 11.484000205993652, train accuracy 65.625 %
# Ep 2 |  train loss: 8.350000381469727, train accuracy 84.375 %
# Ep 2 |  train loss: 10.26099967956543, train accuracy 84.375 %
# Ep 2 |  train loss: 11.593999862670898, train accuracy 65.625 %
# Ep 2 |  train loss: 8.265999794006348, train accuracy 90.625 %
# Ep 2 |  train loss: 11.319000244140625, train accuracy 65.625 %
# Ep 2 |  train loss: 10.321000099182129, train accuracy 84.375 %
# Ep 2 |  train loss: 8.074000358581543, train accuracy 90.625 %
# Ep 2 |  train loss: 6.869999885559082, train accuracy 90.625 %
# Ep 2 |  train loss: 12.234999656677246, train accuracy 78.125 %
# Ep 2 |  train loss: 7.043000221252441, train accuracy 90.625 %
# Ep 2 |  train loss: 9.765000343322754, train accuracy 78.125 %
# Ep 2 |  train loss: 10.456999778747559, train accuracy 81.25 %
# Ep 2 |  train loss: 9.163000106811523, train accuracy 87.5 %
# Ep 2 |  train loss: 10.847999572753906, train accuracy 78.125 %
# Ep 2 |  train loss: 7.978000164031982, train accuracy 81.25 %
# Ep 2 |  train loss: 11.88599967956543, train accuracy 71.875 %
# Ep 2 |  train loss: 10.163999557495117, train accuracy 78.125 %
# Ep 2 |  train loss: 6.6519999504089355, train accuracy 87.5 %
# Ep 2 |  train loss: 9.77299976348877, train accuracy 87.5 %
# Ep 2 |  train loss: 9.755999565124512, train accuracy 78.125 %
# Ep 2 |  train loss: 13.482000350952148, train accuracy 65.625 %
# Ep 2 |  train loss: 9.631999969482422, train accuracy 87.5 %
# Ep 2 |  train loss: 11.342000007629395, train accuracy 81.25 %
# Ep 2 |  train loss: 9.925999641418457, train accuracy 75.0 %
# Ep 2 |  train loss: 7.650000095367432, train accuracy 81.25 %
# Ep 2 |  train loss: 10.039999961853027, train accuracy 81.25 %
# Ep 2 |  train loss: 9.163000106811523, train accuracy 84.375 %
# Ep 2 |  train loss: 9.800000190734863, train accuracy 81.25 %
# Ep 2 |  train loss: 8.907999992370605, train accuracy 81.25 %
# Ep 2 |  train loss: 9.54800033569336, train accuracy 81.25 %
# Ep 2 |  train loss: 13.204000473022461, train accuracy 68.75 %
# Ep 2 |  train loss: 11.182000160217285, train accuracy 75.0 %
# Ep 2 |  train loss: 12.4399995803833, train accuracy 75.0 %
# Ep 2 |  train loss: 11.9399995803833, train accuracy 68.75 %
# Ep 2 |  train loss: 11.395000457763672, train accuracy 71.875 %
# Ep 2 |  train loss: 10.652000427246094, train accuracy 90.625 %
# Ep 2 |  train loss: 7.447999954223633, train accuracy 84.375 %
# Ep 2 |  train loss: 7.947000026702881, train accuracy 84.375 %
# Ep 2 |  train loss: 7.539999961853027, train accuracy 87.5 %
# Ep 2 |  train loss: 12.211999893188477, train accuracy 68.75 %
# Ep 2 |  train loss: 12.6850004196167, train accuracy 53.125 %
# Ep 2 |  train loss: 11.159000396728516, train accuracy 84.375 %
# Ep 2 |  train loss: 8.302000045776367, train accuracy 84.375 %
# Ep 2 |  train loss: 9.642000198364258, train accuracy 81.25 %
# Ep 2 |  train loss: 12.354000091552734, train accuracy 75.0 %
# Ep 2 |  train loss: 9.72599983215332, train accuracy 78.125 %
# Ep 2 |  train loss: 9.982000350952148, train accuracy 84.375 %
# Ep 2 |  train loss: 9.232000350952148, train accuracy 75.0 %
# Ep 2 |  train loss: 9.930000305175781, train accuracy 78.125 %
# Ep 2 |  train loss: 9.60200023651123, train accuracy 84.375 %
# Ep 2 |  train loss: 10.571000099182129, train accuracy 71.875 %
# Ep 2 |  train loss: 10.765000343322754, train accuracy 78.125 %
# Ep 2 |  train loss: 8.121000289916992, train accuracy 93.75 %
# Ep 2 |  train loss: 10.152000427246094, train accuracy 78.125 %
# Ep 2 |  train loss: 9.241000175476074, train accuracy 84.375 %
# Ep 2 |  train loss: 10.571000099182129, train accuracy 75.0 %
# Ep 2 |  train loss: 9.175999641418457, train accuracy 78.125 %
# Ep 2 |  train loss: 9.652999877929688, train accuracy 78.125 %
# Ep 2 |  train loss: 11.107000350952148, train accuracy 68.75 %
# Ep 2 |  train loss: 8.392000198364258, train accuracy 78.125 %
# Ep 2 |  train loss: 8.064000129699707, train accuracy 87.5 %
# Ep 2 |  train loss: 7.973999977111816, train accuracy 87.5 %
# Ep 2 |  train loss: 8.980999946594238, train accuracy 84.375 %
# Ep 2 |  train loss: 11.119000434875488, train accuracy 71.875 %
# Ep 2 |  train loss: 7.4770002365112305, train accuracy 90.625 %
# Ep 2 |  train loss: 11.157999992370605, train accuracy 78.125 %
# Ep 2 |  train loss: 12.175000190734863, train accuracy 75.0 %
# Ep 2 |  train loss: 10.190999984741211, train accuracy 84.375 %
# Ep 2 |  train loss: 8.859000205993652, train accuracy 87.5 %
# Ep 2 |  train loss: 8.675000190734863, train accuracy 84.375 %
# Ep 2 |  train loss: 12.178999900817871, train accuracy 68.75 %
# Ep 2 |  train loss: 10.64900016784668, train accuracy 68.75 %
# Ep 2 |  train loss: 8.661999702453613, train accuracy 90.625 %
# Ep 2 |  train loss: 9.958000183105469, train accuracy 71.875 %
# Ep 2 |  train loss: 10.638999938964844, train accuracy 75.0 %
# Ep 2 |  train loss: 11.383999824523926, train accuracy 65.625 %
# Ep 2 |  train loss: 9.048999786376953, train accuracy 75.0 %
# Ep 2 |  train loss: 11.680999755859375, train accuracy 75.0 %
# Ep 2 |  train loss: 10.574000358581543, train accuracy 71.875 %
# Ep 2 |  train loss: 10.312000274658203, train accuracy 68.75 %
# Ep 2 |  train loss: 12.605999946594238, train accuracy 78.125 %
# Ep 2 |  train loss: 11.8149995803833, train accuracy 65.625 %
# Ep 2 |  train loss: 8.847999572753906, train accuracy 87.5 %
# Ep 2 |  train loss: 10.590999603271484, train accuracy 78.125 %
# Ep 2 |  train loss: 5.329999923706055, train accuracy 93.75 %
# Ep 2 |  train loss: 10.909000396728516, train accuracy 68.75 %
# Ep 2 |  train loss: 7.8979997634887695, train accuracy 84.375 %
# Ep 2 |  train loss: 9.354999542236328, train accuracy 78.125 %
# Ep 2 |  train loss: 8.406999588012695, train accuracy 81.25 %
# Ep 2 |  train loss: 7.921000003814697, train accuracy 93.75 %
# Ep 2 |  train loss: 8.970000267028809, train accuracy 84.375 %
# Ep 2 |  train loss: 12.305999755859375, train accuracy 68.75 %
# Ep 2 |  train loss: 10.657999992370605, train accuracy 75.0 %
# Ep 2 |  train loss: 9.758999824523926, train accuracy 84.375 %
# Ep 2 |  train loss: 13.704000473022461, train accuracy 65.625 %
# Ep 2 |  train loss: 9.038999557495117, train accuracy 84.375 %
# Ep 2 |  train loss: 11.593000411987305, train accuracy 78.125 %
# Ep 2 |  train loss: 7.8470001220703125, train accuracy 87.5 %
# Ep 2 |  train loss: 8.005999565124512, train accuracy 75.0 %
# Ep 2 |  train loss: 10.592000007629395, train accuracy 87.5 %
# Ep 2 |  train loss: 11.281999588012695, train accuracy 81.25 %
# Ep 2 |  train loss: 11.866000175476074, train accuracy 71.875 %
# Ep 2 |  train loss: 11.126999855041504, train accuracy 68.75 %
# Ep 2 |  train loss: 8.42199993133545, train accuracy 81.25 %
# Ep 2 |  train loss: 8.968999862670898, train accuracy 78.125 %
# Ep 2 |  train loss: 8.711999893188477, train accuracy 81.25 %
# Ep 2 |  train loss: 12.218999862670898, train accuracy 68.75 %
# Ep 2 |  train loss: 9.256999969482422, train accuracy 90.625 %
# Ep 2 |  train loss: 9.75, train accuracy 78.125 %
# Ep 2 |  train loss: 15.852999687194824, train accuracy 68.75 %
# Ep 2 |  train loss: 8.916000366210938, train accuracy 84.375 %
# Ep 2 |  train loss: 11.993000030517578, train accuracy 71.875 %
# Ep 2 |  train loss: 9.557999610900879, train accuracy 84.375 %
# Ep 2 |  train loss: 12.62399959564209, train accuracy 68.75 %
# Ep 2 |  train loss: 11.178999900817871, train accuracy 75.0 %
# Ep 2 |  train loss: 11.407999992370605, train accuracy 68.75 %
# Ep 2 |  train loss: 12.357000350952148, train accuracy 71.875 %
# Ep 2 |  train loss: 12.838000297546387, train accuracy 59.375 %
# Ep 2 |  train loss: 8.99899959564209, train accuracy 84.375 %
# Ep 2 |  train loss: 8.6850004196167, train accuracy 84.375 %
# Ep 2 |  train loss: 9.607000350952148, train accuracy 84.375 %
# Ep 2 |  train loss: 7.013000011444092, train accuracy 90.625 %
# Ep 2 |  train loss: 9.645000457763672, train accuracy 81.25 %
# Ep 2 |  train loss: 11.901000022888184, train accuracy 78.125 %
# Ep 2 |  train loss: 10.11299991607666, train accuracy 78.125 %
# Ep 2 |  train loss: 9.076000213623047, train accuracy 81.25 %
# Ep 2 |  train loss: 11.760000228881836, train accuracy 78.125 %
# Ep 2 |  train loss: 10.291999816894531, train accuracy 81.25 %
# Ep 2 |  train loss: 11.73799991607666, train accuracy 68.75 %
# Ep 2 |  train loss: 9.04699993133545, train accuracy 78.125 %
# Ep 2 |  train loss: 9.116000175476074, train accuracy 84.375 %
# Ep 2 |  train loss: 8.637999534606934, train accuracy 81.25 %
# Ep 2 |  train loss: 10.635000228881836, train accuracy 75.0 %
# Ep 2 |  train loss: 8.97700023651123, train accuracy 84.375 %
# Ep 2 |  train loss: 6.178999900817871, train accuracy 93.75 %
# Ep 2 |  train loss: 9.694999694824219, train accuracy 78.125 %
# Ep 2 |  train loss: 7.63700008392334, train accuracy 87.5 %
# Ep 2 |  train loss: 8.086999893188477, train accuracy 84.375 %
# Ep 2 |  train loss: 6.6020002365112305, train accuracy 87.5 %
# Ep 2 |  train loss: 8.392999649047852, train accuracy 87.5 %
# Ep 2 |  train loss: 10.918999671936035, train accuracy 81.25 %
# Ep 2 |  train loss: 10.984000205993652, train accuracy 75.0 %

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp("let's us thing so")

# %%
for token in doc:
    print(token.text, token.lemma_, token.is_oov, token.is_punct, token.orth_)
# Out:
# let let True False let
# 's -PRON- True False 's
# us -PRON- True False us
# thing thing True False thing
# so so True False so

# %%
lexeme = nlp.vocab[doc[1].text]

# %%
lexeme.text, lexeme.norm_, lexeme.is_oov
# Out:
# ("'s", "'s", True)

# %%
lexeme.vector
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-23ad11a48283> in <module>
# ----> 1 lexeme.vector
#
# lexeme.pyx in spacy.lexeme.Lexeme.vector.__get__()
#
# ValueError: [E010] Word vectors set to length 0. This may be because you don't have a model installed or loaded, or because your model doesn't include word vectors. For more info, see the docs:
# https://spacy.io/usage/models

# %% [markdown]
# ### TODO:
#
# 1. **Create a pipe element to perform polarity cutoff:**
#
# ```
# word_polarity = pass # dict of the form word: polarity
# polarity_filter = PolarityFilter(data = word_polarity,
#                                  max_pol = 1.3,
#                                  min_pol = -1.3, # tokens whos polarity between [min_pol, max_pol]
#                                                  # will be tagged 'in_doc_vectors' = False
#                                  tag = 'in_doc_vector' # the tag in which to store the True of False result
#                                 )
#
# # create an element that computes a doc vector
# # only by considering the elements tagged as
# # sepcifified by 'tag'
# doc_vectorizer = DocVectorizer(tag = 'in_doc_vector')
#
# nlp.add_pipe(polarity_filter)
# nlp.add_pipe(doc_vectorizer)
# ```
#
# 2. **create a module in SyferText where the Dataset object for IMDB movie reviews can be imported:**
#
# (or DatasetIMDB can just return a list of sets, each is of the form [{'review': <string>, 'sentiment': int}, ...])
# and then we create the dataset object out of this
#
# ```
# from syfertext.datasets.imdb import DatasetIMDB
# from torch.utils.data import DataLoader
#
# # This loads the IMDB PyTorch Dataset object
# # it will download the dataset, load it locally
# # then sends it to the specified workers
# # we can specify the proportion each worker takes
# # of each of the classes. for instance
# # bob here takes 30% of positive examples from the
# # original dataset and 20% of its negative examples
# trainset = DatasetIMDB(bob, alice,
#                        dist = {'bob': {'pos' : 30, 'neg': 20},
#                                'alice': {'pos' 70, 'neg': 50}},
#                        mode = 'train'
#                        pipes = [polarity_filter, doc_vectorizer]
#                       )
#
# valset = DatasetIMDB(bob, alice,
#                      dist = {'bob': {'pos' : 50, 'neg': 50},
#                              'alice': {'pos' 50, 'neg': 50}},
#                      mode = 'val',
#                      pipes = [polarity_filter, doc_vectorizer]
#                     )
#
# # Create a torch data loaders
# trainloader = DataLoader(trainset, shuffle = True,
#                          batchsize = 16, workers = 2)
#
# valloader = DataLoader(valset, shuffle = False,
#                          batchsize = 16, workers = 2)
#
# ```
